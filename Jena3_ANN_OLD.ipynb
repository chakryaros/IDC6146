# %% [markdown]
# # Optimizer Example
# Jena Climate ANN example showing comparison between optimizers.
# This is a regression model, using 3-hour data.
#
# Richard Henry, 18-Jul-2024

# %%
#Import Libararies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %% [markdown]
# Test Libraries

# %%
# Check python version
from platform import python_version
print(python_version())
#3.12.3
# Out:
# 3.12.3

# %%
# Check tensorflow version
tf.__version__
#2.16.1
# Out:
# '2.16.2'

# %%
# Check keras version
tf.keras.__version__
#3.4.1
# Out:
# '3.4.1'

# %% [markdown]
# |Dataset|Architecture|Group|Type|
# |---|---|---|---|
# |Jena3|ANN|Contemporary|Regression|

# %%
# Load Data (Already cleaned and decimated)
df3=pd.read_csv('dataset/Jena_climate/cleanJena3.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23363 entries, 0 to 23362
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   p (mbar)       23363 non-null  float64
#  1   VPact (mbar)   23363 non-null  float64
#  2   Tdew (degC)    23363 non-null  float64
#  3   T (degC)       23363 non-null  float64
#  4   max. wv (m/s)  23363 non-null  float64
#  5   NSwind         23363 non-null  float64
#  6   EWwind         23363 non-null  float64
#  7   year           23363 non-null  int64
#  8   month          23363 non-null  int64
#  9   day            23363 non-null  int64
#  10  hour           23363 non-null  int64
# dtypes: float64(7), int64(4)
# memory usage: 2.0 MB

# %%
df3.describe()
# Out:
#            p (mbar)  VPact (mbar)   Tdew (degC)      T (degC)  max. wv (m/s)  \
# count  23363.000000  23363.000000  23363.000000  23363.000000   23363.000000
# mean     989.216246      9.533017      4.954671      9.456338       3.533382
# std        8.353071      4.184973      6.730860      8.428081       2.339862
# min      942.720000      0.810000    -24.800000    -22.760000       0.000000
# 25%      984.200000      6.220000      0.240000      3.340000       1.760000
# 50%      989.590000      8.860000      5.210000      9.440000       2.980000
# 75%      994.730000     12.360000     10.080000     15.480000       4.730000
# max     1015.170000     28.040000     22.940000     36.460000      18.780000
#
#              NSwind        EWwind          year         month           day  \
# count  23363.000000  23363.000000  23363.000000  23363.000000  23363.000000
# mean      -0.631798     -0.415655   2012.497068      6.517399     15.713222
# std        1.983549      1.553730      2.289905      3.448433      8.799298
# min      -10.783959     -7.148867   2009.000000      1.000000      1.000000
# 25%       -1.480647     -1.372670   2010.000000      4.000000      8.000000
# 50%       -0.637933     -0.296919   2012.000000      7.000000     16.000000
# 75%        0.306138      0.432981   2014.000000     10.000000     23.000000
# max        7.709359      6.966350   2017.000000     12.000000     31.000000
#
#                hour
# count  23363.000000
# mean      10.500449
# std        6.873702
# min        0.000000
# 25%        6.000000
# 50%       12.000000
# 75%       15.000000
# max       21.000000

# %%
# Model / data parameters
blk_len=16*8      #Look back at two weeks of data
stp_len=8         #look forward 24 hours
row_len=len(df3)   #total records (last target location)
col_len=11         #total variables
bat_len=64*8      #batch size of 2 months
epo_len=32         #32 epochs
val_fra=0.2        #use 20% of data for validation
pas_len=blk_len+stp_len  #first target location
cut_len=row_len-pas_len  #last start of predictor location

# %%
# %%time
# Reformat
y_train=df3['T (degC)'].iloc[pas_len:].to_numpy()  #pull out all the targets
#start building predictor deck
xAll=df3.to_numpy()
xTrain=np.zeros([cut_len,blk_len,col_len])
for i in range(cut_len):
    for j in range(blk_len):
            xTrain[i][j][:]=xAll[i+j][:]
# Out:
# CPU times: total: 2.11 s
# Wall time: 2.23 s

# %%
#Normalize Input Data
fixMe=tf.keras.layers.Normalization()
fixMe.adapt(xTrain)

# %%
# Build & train model functions
def model_core():
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape=(blk_len,col_len)),
            fixMe,
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(64,
                                  activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(32,
                                  activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(1,
                                  activation='linear')
        ]
    )
    return model
def model_build(myOpti):
    #Build it exactly the same every time
    tf.random.set_seed(19)
    model=model_core()
    model.compile(loss='mean_squared_error',
                  optimizer=myOpti,
                  metrics=['mean_absolute_error'])
    # Reduce variation in training...
    tf.random.set_seed(17)
    print("History Match:")
    myHis=model.fit(xTrain,
                    y_train,
                    batch_size=bat_len,
                    epochs=epo_len,
                    validation_split=val_fra)
    print("\n")
    print("Evaluate Model:")
    myEva=model.evaluate(xTrain,
                         y_train,
                         batch_size=bat_len)
    print("All Sample MSE:",myEva[0])
    print("All Sample MAE:",myEva[1])
    print("\n")
    print("Make Predictions:")
    myPre=model.predict(xTrain)
    print("\n")
    print("Timing:")
    return myHis,myPre

# %% [markdown]
# ### First Model, Adam

# %%
# %%time
h0,p0=model_build('adam')
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 69.9668 - mean_absolute_error: 6.4587 - val_loss: 20.5570 - val_mean_absolute_error: 3.6450
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.8528 - mean_absolute_error: 3.7660 - val_loss: 15.1463 - val_mean_absolute_error: 3.0763
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.9346 - mean_absolute_error: 3.3929 - val_loss: 14.0211 - val_mean_absolute_error: 2.9850
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.2851 - mean_absolute_error: 3.1722 - val_loss: 13.1794 - val_mean_absolute_error: 2.8650
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.5100 - mean_absolute_error: 3.0629 - val_loss: 12.9040 - val_mean_absolute_error: 2.8247
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.3849 - mean_absolute_error: 2.9650 - val_loss: 12.8043 - val_mean_absolute_error: 2.8020
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.0061 - mean_absolute_error: 2.9132 - val_loss: 12.7265 - val_mean_absolute_error: 2.8077
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.3564 - mean_absolute_error: 2.8559 - val_loss: 12.8753 - val_mean_absolute_error: 2.8055
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.7908 - mean_absolute_error: 2.7838 - val_loss: 12.7928 - val_mean_absolute_error: 2.7935
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.3312 - mean_absolute_error: 2.7363 - val_loss: 12.7844 - val_mean_absolute_error: 2.7987
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.9265 - mean_absolute_error: 2.6759 - val_loss: 13.1487 - val_mean_absolute_error: 2.8362
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.4400 - mean_absolute_error: 2.6350 - val_loss: 13.0467 - val_mean_absolute_error: 2.8208
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.0143 - mean_absolute_error: 2.5909 - val_loss: 13.0430 - val_mean_absolute_error: 2.8128
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2700 - mean_absolute_error: 2.6246 - val_loss: 13.3287 - val_mean_absolute_error: 2.8508
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.9480 - mean_absolute_error: 2.5758 - val_loss: 13.4773 - val_mean_absolute_error: 2.8635
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.8374 - mean_absolute_error: 2.5573 - val_loss: 13.8460 - val_mean_absolute_error: 2.9109
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.4695 - mean_absolute_error: 2.5088 - val_loss: 13.1199 - val_mean_absolute_error: 2.8419
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5101 - mean_absolute_error: 2.5261 - val_loss: 13.4198 - val_mean_absolute_error: 2.8730
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.1081 - mean_absolute_error: 2.4813 - val_loss: 13.3959 - val_mean_absolute_error: 2.8744
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0830 - mean_absolute_error: 2.4532 - val_loss: 13.6496 - val_mean_absolute_error: 2.8934
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8652 - mean_absolute_error: 2.4280 - val_loss: 13.5015 - val_mean_absolute_error: 2.8811
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9269 - mean_absolute_error: 2.4272 - val_loss: 13.7822 - val_mean_absolute_error: 2.9135
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5808 - mean_absolute_error: 2.4101 - val_loss: 13.2997 - val_mean_absolute_error: 2.8612
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5738 - mean_absolute_error: 2.3993 - val_loss: 13.2995 - val_mean_absolute_error: 2.8620
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3119 - mean_absolute_error: 2.3769 - val_loss: 13.2716 - val_mean_absolute_error: 2.8553
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3949 - mean_absolute_error: 2.3733 - val_loss: 13.8077 - val_mean_absolute_error: 2.9093
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3501 - mean_absolute_error: 2.3710 - val_loss: 13.4714 - val_mean_absolute_error: 2.8951
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3281 - mean_absolute_error: 2.3655 - val_loss: 13.1675 - val_mean_absolute_error: 2.8443
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2851 - mean_absolute_error: 2.3543 - val_loss: 13.4934 - val_mean_absolute_error: 2.8905
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2587 - mean_absolute_error: 2.3409 - val_loss: 13.4389 - val_mean_absolute_error: 2.8790
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8044 - mean_absolute_error: 2.2950 - val_loss: 13.4178 - val_mean_absolute_error: 2.8599
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6241 - mean_absolute_error: 2.2754 - val_loss: 13.3065 - val_mean_absolute_error: 2.8598
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8726 - mean_absolute_error: 1.7180
# All Sample MSE: 6.387683391571045
# All Sample MAE: 1.92998468875885
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 767us/step
#
#
# Timing:
# CPU times: total: 4.17 s
# Wall time: 9.09 s

# %%
plt.plot(h0.history['val_loss'], color='blue')
plt.plot(h0.history['loss'], color='orange')
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['validation','training'])
plt.title('Adam')
plt.grid()
plt.show()

# %%
plt.plot(y_train, color='cyan')
plt.plot(p0.flatten(), color='magenta')
plt.ylabel('Temperature [degC]')
plt.xlabel('Hour')
plt.legend(['training','prediction'])
plt.title('Adam')
plt.grid()
plt.show()

# %%
plt.scatter(y_train,p0.flatten())
plt.ylabel('Estimated Temperature [degC]')
plt.xlabel('Measured Temperature [degC]')
plt.title('Adam')
plt.grid()
plt.ylim([-20,40])
plt.show()

# %% [markdown]
# ### Second Model, AdaGrad

# %%
# %%time
h1,p1=model_build('adagrad')
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 98.0183 - mean_absolute_error: 7.9606 - val_loss: 69.1007 - val_mean_absolute_error: 6.7660
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.4158 - mean_absolute_error: 5.0757 - val_loss: 45.9302 - val_mean_absolute_error: 5.3778
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.0322 - mean_absolute_error: 4.5957 - val_loss: 35.3711 - val_mean_absolute_error: 4.6811
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.8576 - mean_absolute_error: 4.3014 - val_loss: 29.2466 - val_mean_absolute_error: 4.2506
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.4981 - mean_absolute_error: 4.1133 - val_loss: 24.8559 - val_mean_absolute_error: 3.9266
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25.3551 - mean_absolute_error: 3.9603 - val_loss: 22.7482 - val_mean_absolute_error: 3.7624
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.0208 - mean_absolute_error: 3.8651 - val_loss: 21.0963 - val_mean_absolute_error: 3.6295
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.9941 - mean_absolute_error: 3.8391 - val_loss: 20.2070 - val_mean_absolute_error: 3.5521
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.0475 - mean_absolute_error: 3.7681 - val_loss: 19.1816 - val_mean_absolute_error: 3.4658
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.5520 - mean_absolute_error: 3.7215 - val_loss: 18.3625 - val_mean_absolute_error: 3.3974
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.0065 - mean_absolute_error: 3.6823 - val_loss: 17.8150 - val_mean_absolute_error: 3.3456
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.1672 - mean_absolute_error: 3.6017 - val_loss: 17.4991 - val_mean_absolute_error: 3.3139
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.1545 - mean_absolute_error: 3.6077 - val_loss: 16.9508 - val_mean_absolute_error: 3.2665
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.7647 - mean_absolute_error: 3.5680 - val_loss: 16.6199 - val_mean_absolute_error: 3.2333
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.3887 - mean_absolute_error: 3.5419 - val_loss: 16.3450 - val_mean_absolute_error: 3.2055
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.4335 - mean_absolute_error: 3.5421 - val_loss: 16.0090 - val_mean_absolute_error: 3.1717
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.2656 - mean_absolute_error: 3.5281 - val_loss: 15.6420 - val_mean_absolute_error: 3.1399
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.2944 - mean_absolute_error: 3.4391 - val_loss: 15.4083 - val_mean_absolute_error: 3.1166
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.5270 - mean_absolute_error: 3.4583 - val_loss: 15.2259 - val_mean_absolute_error: 3.0949
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.1933 - mean_absolute_error: 3.4320 - val_loss: 14.9853 - val_mean_absolute_error: 3.0704
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.0238 - mean_absolute_error: 3.4068 - val_loss: 14.8538 - val_mean_absolute_error: 3.0569
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.7073 - mean_absolute_error: 3.3695 - val_loss: 14.7227 - val_mean_absolute_error: 3.0440
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.4378 - mean_absolute_error: 3.3568 - val_loss: 14.5451 - val_mean_absolute_error: 3.0245
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.8641 - mean_absolute_error: 3.3786 - val_loss: 14.4267 - val_mean_absolute_error: 3.0101
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.9534 - mean_absolute_error: 3.4055 - val_loss: 14.2991 - val_mean_absolute_error: 2.9986
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.2835 - mean_absolute_error: 3.3372 - val_loss: 14.1746 - val_mean_absolute_error: 2.9868
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.6159 - mean_absolute_error: 3.2914 - val_loss: 14.1349 - val_mean_absolute_error: 2.9777
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9686 - mean_absolute_error: 3.3251 - val_loss: 13.9870 - val_mean_absolute_error: 2.9672
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.7155 - mean_absolute_error: 3.2773 - val_loss: 13.9445 - val_mean_absolute_error: 2.9589
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9165 - mean_absolute_error: 3.3039 - val_loss: 13.7757 - val_mean_absolute_error: 2.9444
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.5834 - mean_absolute_error: 3.2639 - val_loss: 13.7452 - val_mean_absolute_error: 2.9425
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.5905 - mean_absolute_error: 3.2668 - val_loss: 13.7119 - val_mean_absolute_error: 2.9319
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.0503 - mean_absolute_error: 2.5927
# All Sample MSE: 11.762249946594238
# All Sample MAE: 2.6914596557617188
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step
#
#
# Timing:
# CPU times: total: 3.62 s
# Wall time: 7.69 s

# %% [markdown]
# ### Third Model, Stochastic Gradient Descent with Nesterov Momentum

# %%
opt012=tf.keras.optimizers.SGD(momentum=0.5,
                               nesterov=True,
                               name='nSGD'
                              )

# %%
# %%time
h2,p2=model_build(opt012)
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 198.9450 - mean_absolute_error: 10.1583 - val_loss: 42.7129 - val_mean_absolute_error: 5.0763
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.1317 - mean_absolute_error: 5.1860 - val_loss: 31.8441 - val_mean_absolute_error: 4.3364
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.0696 - mean_absolute_error: 4.8620 - val_loss: 31.1710 - val_mean_absolute_error: 4.3327
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.1279 - mean_absolute_error: 4.7280 - val_loss: 30.3016 - val_mean_absolute_error: 4.2907
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.8679 - mean_absolute_error: 4.6137 - val_loss: 29.9048 - val_mean_absolute_error: 4.2762
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.7018 - mean_absolute_error: 4.5448 - val_loss: 230.0812 - val_mean_absolute_error: 10.1682
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - mean_absolute_error: nan
# All Sample MSE: nan
# All Sample MAE: nan
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 730us/step
#
#
# Timing:
# CPU times: total: 3.34 s
# Wall time: 7.68 s

# %% [markdown]
# ### Fourth Model, Root Mean Squared Propagation

# %%
# %%time
h3,p3=model_build('rmsprop')
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 60.7928 - mean_absolute_error: 5.9369 - val_loss: 19.4578 - val_mean_absolute_error: 3.5236
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.3078 - mean_absolute_error: 3.6105 - val_loss: 15.9083 - val_mean_absolute_error: 3.1532
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.2783 - mean_absolute_error: 3.3278 - val_loss: 14.0166 - val_mean_absolute_error: 2.9998
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.0822 - mean_absolute_error: 3.1182 - val_loss: 15.9887 - val_mean_absolute_error: 3.1484
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.8262 - mean_absolute_error: 3.0877 - val_loss: 16.5690 - val_mean_absolute_error: 3.2277
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.8496 - mean_absolute_error: 3.0093 - val_loss: 13.4473 - val_mean_absolute_error: 2.9186
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.0850 - mean_absolute_error: 2.9343 - val_loss: 14.8425 - val_mean_absolute_error: 3.1087
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.6919 - mean_absolute_error: 2.8702 - val_loss: 13.1231 - val_mean_absolute_error: 2.8326
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.9186 - mean_absolute_error: 2.8866 - val_loss: 13.6883 - val_mean_absolute_error: 2.8961
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.3533 - mean_absolute_error: 2.7354 - val_loss: 12.7863 - val_mean_absolute_error: 2.8119
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.5086 - mean_absolute_error: 2.7522 - val_loss: 16.1090 - val_mean_absolute_error: 3.1408
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.4819 - mean_absolute_error: 2.7431 - val_loss: 17.4721 - val_mean_absolute_error: 3.2933
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.7571 - mean_absolute_error: 2.7831 - val_loss: 13.9909 - val_mean_absolute_error: 2.9829
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.8935 - mean_absolute_error: 2.6689 - val_loss: 13.5030 - val_mean_absolute_error: 2.8787
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.6699 - mean_absolute_error: 2.6368 - val_loss: 14.2357 - val_mean_absolute_error: 2.9699
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.1245 - mean_absolute_error: 2.6740 - val_loss: 13.1206 - val_mean_absolute_error: 2.8566
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.7167 - mean_absolute_error: 2.6402 - val_loss: 12.6470 - val_mean_absolute_error: 2.7921
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.9655 - mean_absolute_error: 2.5607 - val_loss: 13.8848 - val_mean_absolute_error: 2.9349
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.8492 - mean_absolute_error: 2.5498 - val_loss: 13.1854 - val_mean_absolute_error: 2.8557
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.9624 - mean_absolute_error: 2.5518 - val_loss: 13.4964 - val_mean_absolute_error: 2.8938
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.7032 - mean_absolute_error: 2.5371 - val_loss: 12.4717 - val_mean_absolute_error: 2.8050
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.4676 - mean_absolute_error: 2.4965 - val_loss: 13.3379 - val_mean_absolute_error: 2.8717
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.6021 - mean_absolute_error: 2.5151 - val_loss: 13.3997 - val_mean_absolute_error: 2.8762
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.4892 - mean_absolute_error: 2.5039 - val_loss: 14.9542 - val_mean_absolute_error: 3.0591
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.8592 - mean_absolute_error: 2.5221 - val_loss: 13.5468 - val_mean_absolute_error: 2.9056
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.4229 - mean_absolute_error: 2.4823 - val_loss: 13.0368 - val_mean_absolute_error: 2.8485
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8309 - mean_absolute_error: 2.4002 - val_loss: 14.9882 - val_mean_absolute_error: 3.0287
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9860 - mean_absolute_error: 2.4284 - val_loss: 13.1232 - val_mean_absolute_error: 2.8346
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8665 - mean_absolute_error: 2.4191 - val_loss: 12.5738 - val_mean_absolute_error: 2.7833
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6316 - mean_absolute_error: 2.3912 - val_loss: 18.3442 - val_mean_absolute_error: 3.3712
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0357 - mean_absolute_error: 2.4376 - val_loss: 14.5435 - val_mean_absolute_error: 3.0190
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9591 - mean_absolute_error: 2.4141 - val_loss: 13.9992 - val_mean_absolute_error: 2.9343
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4100 - mean_absolute_error: 1.9803
# All Sample MSE: 7.779512882232666
# All Sample MAE: 2.1524062156677246
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step
#
#
# Timing:
# CPU times: total: 4.31 s
# Wall time: 8.44 s

# %%
plt.plot(h0.history['val_loss'],color='blue')
plt.plot(h1.history['val_loss'],color='orange',marker='o')
plt.plot(h2.history['val_loss'],color='cyan',marker='x')
plt.plot(h3.history['val_loss'],color='magenta',marker='s')
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['Adam','AdaGrad','SGD+Nest','RMSProp'])
plt.title('Missing in Action')
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_loss'],color='blue')
plt.plot(h1.history['val_loss'],color='orange',marker='o')
plt.plot(h2.history['val_loss'],color='cyan',marker='x')
plt.plot(h3.history['val_loss'],color='magenta',marker='s')
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['Adam','AdaGrad','SGD+Nest','RMSProp'])
plt.title('Photo Finish?')
plt.ylim([10,20])
plt.grid()
plt.show()

# %% [markdown]
# ### Model Summary

# %%
m=model_core()
m.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)        │ (None, 128, 11)             │              23 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 1408)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 64)                  │          90,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 92,312 (360.60 KB)
#  Trainable params: 92,289 (360.50 KB)
#  Non-trainable params: 23 (96.00 B)
