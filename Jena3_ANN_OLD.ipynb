# %% [markdown]
# # Optimizer Example
# Jena Climate RNN example showing comparison between optimizers.
# This is a regression model, using 3-hour data.
#
# Richard Henry, 18-Jul-2024

# %%
#Import Libararies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %% [markdown]
# Test Libraries

# %%
# Check python version
from platform import python_version
print(python_version())
#3.12.3
# Out:
# 3.12.3

# %%
# Check tensorflow version
tf.__version__
#2.16.1
# Out:
# '2.16.2'

# %%
# Check keras version
tf.keras.__version__
#3.4.1
# Out:
# '3.4.1'

# %% [markdown]
# # Jena ANN

# %%
# Load Data (Already cleaned and decimated)
df3=pd.read_csv('dataset/Jena_climate/cleanJena3.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23363 entries, 0 to 23362
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   p (mbar)       23363 non-null  float64
#  1   VPact (mbar)   23363 non-null  float64
#  2   Tdew (degC)    23363 non-null  float64
#  3   T (degC)       23363 non-null  float64
#  4   max. wv (m/s)  23363 non-null  float64
#  5   NSwind         23363 non-null  float64
#  6   EWwind         23363 non-null  float64
#  7   year           23363 non-null  int64
#  8   month          23363 non-null  int64
#  9   day            23363 non-null  int64
#  10  hour           23363 non-null  int64
# dtypes: float64(7), int64(4)
# memory usage: 2.0 MB

# %%
df3.describe()
# Out:
#            p (mbar)  VPact (mbar)   Tdew (degC)      T (degC)  max. wv (m/s)  \
# count  23363.000000  23363.000000  23363.000000  23363.000000   23363.000000
# mean     989.216246      9.533017      4.954671      9.456338       3.533382
# std        8.353071      4.184973      6.730860      8.428081       2.339862
# min      942.720000      0.810000    -24.800000    -22.760000       0.000000
# 25%      984.200000      6.220000      0.240000      3.340000       1.760000
# 50%      989.590000      8.860000      5.210000      9.440000       2.980000
# 75%      994.730000     12.360000     10.080000     15.480000       4.730000
# max     1015.170000     28.040000     22.940000     36.460000      18.780000
#
#              NSwind        EWwind          year         month           day  \
# count  23363.000000  23363.000000  23363.000000  23363.000000  23363.000000
# mean      -0.631798     -0.415655   2012.497068      6.517399     15.713222
# std        1.983549      1.553730      2.289905      3.448433      8.799298
# min      -10.783959     -7.148867   2009.000000      1.000000      1.000000
# 25%       -1.480647     -1.372670   2010.000000      4.000000      8.000000
# 50%       -0.637933     -0.296919   2012.000000      7.000000     16.000000
# 75%        0.306138      0.432981   2014.000000     10.000000     23.000000
# max        7.709359      6.966350   2017.000000     12.000000     31.000000
#
#                hour
# count  23363.000000
# mean      10.500449
# std        6.873702
# min        0.000000
# 25%        6.000000
# 50%       12.000000
# 75%       15.000000
# max       21.000000

# %%
# Model / data parameters
blk_len=16*8      #Look back at two weeks of data
stp_len=8         #look forward 24 hours
row_len=len(df3)   #total records (last target location)
col_len=11         #total variables
bat_len=64*8      #batch size of 2 months
epo_len=32         #32 epochs
val_fra=0.2        #use 20% of data for validation
pas_len=blk_len+stp_len  #first target location
cut_len=row_len-pas_len  #last start of predictor location

# %%
# %%time
# Reformat
y_train=df3['T (degC)'].iloc[pas_len:].to_numpy()  #pull out all the targets
#start building predictor deck
xAll=df3.to_numpy()
xTrain=np.zeros([cut_len,blk_len,col_len])
for i in range(cut_len):
    for j in range(blk_len):
            xTrain[i][j][:]=xAll[i+j][:]
# Out:
# CPU times: total: 2.06 s
# Wall time: 2.19 s

# %%
#Normalize Input Data
fixMe=tf.keras.layers.Normalization()
fixMe.adapt(xTrain)

# %%
# Build & train model function
def model_build(myOpti):
    #Build it exactly the same every time
    tf.random.set_seed(19)
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape=(blk_len,col_len)),
            fixMe,
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(64,
                                  activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(32,
                                  activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(1,
                                  activation='linear')
        ]
    )
    model.compile(loss='mean_squared_error',
                  optimizer=myOpti,
                  metrics=['mean_absolute_error'])
    myHis=model.fit(xTrain,
                    y_train,
                    batch_size=bat_len,
                    epochs=epo_len,
                    validation_split=val_fra)
    myPre=model.predict(xTrain)
    return myHis,myPre

# %% [markdown]
# ### First Model, Adam

# %%
# %%time
h0,p0=model_build('adam')
# Out:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 76.8124 - mean_absolute_error: 6.8541 - val_loss: 21.4767 - val_mean_absolute_error: 3.7109
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.5130 - mean_absolute_error: 3.8819 - val_loss: 15.5330 - val_mean_absolute_error: 3.1400
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.5040 - mean_absolute_error: 3.4662 - val_loss: 13.9753 - val_mean_absolute_error: 2.9676
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.1103 - mean_absolute_error: 3.2411 - val_loss: 13.6473 - val_mean_absolute_error: 2.9137
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.7747 - mean_absolute_error: 3.0869 - val_loss: 13.3762 - val_mean_absolute_error: 2.8788
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.5257 - mean_absolute_error: 2.9805 - val_loss: 13.1672 - val_mean_absolute_error: 2.8381
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.7791 - mean_absolute_error: 2.9007 - val_loss: 12.9694 - val_mean_absolute_error: 2.8313
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.4378 - mean_absolute_error: 2.8512 - val_loss: 13.6501 - val_mean_absolute_error: 2.8884
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.6699 - mean_absolute_error: 2.7776 - val_loss: 13.1079 - val_mean_absolute_error: 2.8218
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.8846 - mean_absolute_error: 2.7845 - val_loss: 13.1006 - val_mean_absolute_error: 2.8377
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.1229 - mean_absolute_error: 2.7142 - val_loss: 13.2089 - val_mean_absolute_error: 2.8329
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.3248 - mean_absolute_error: 2.7200 - val_loss: 13.2302 - val_mean_absolute_error: 2.8429
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.9916 - mean_absolute_error: 2.6951 - val_loss: 13.1101 - val_mean_absolute_error: 2.8307
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.6796 - mean_absolute_error: 2.6397 - val_loss: 12.8540 - val_mean_absolute_error: 2.8146
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.4377 - mean_absolute_error: 2.6379 - val_loss: 13.7625 - val_mean_absolute_error: 2.8992
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.3126 - mean_absolute_error: 2.6101 - val_loss: 13.1753 - val_mean_absolute_error: 2.8348
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.7976 - mean_absolute_error: 2.5537 - val_loss: 13.2503 - val_mean_absolute_error: 2.8454
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.8532 - mean_absolute_error: 2.5440 - val_loss: 13.4097 - val_mean_absolute_error: 2.8678
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4609 - mean_absolute_error: 2.5046 - val_loss: 13.8746 - val_mean_absolute_error: 2.9300
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.6480 - mean_absolute_error: 2.5324 - val_loss: 13.6090 - val_mean_absolute_error: 2.8961
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4937 - mean_absolute_error: 2.5033 - val_loss: 12.9796 - val_mean_absolute_error: 2.8378
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.0807 - mean_absolute_error: 2.4528 - val_loss: 13.9436 - val_mean_absolute_error: 2.9412
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.2590 - mean_absolute_error: 2.4634 - val_loss: 13.2465 - val_mean_absolute_error: 2.8739
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8621 - mean_absolute_error: 2.4299 - val_loss: 13.6498 - val_mean_absolute_error: 2.8983
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7446 - mean_absolute_error: 2.4078 - val_loss: 13.3673 - val_mean_absolute_error: 2.8726
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3894 - mean_absolute_error: 2.3639 - val_loss: 14.3711 - val_mean_absolute_error: 2.9960
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8575 - mean_absolute_error: 2.4154 - val_loss: 13.3395 - val_mean_absolute_error: 2.8833
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5166 - mean_absolute_error: 2.3911 - val_loss: 13.4129 - val_mean_absolute_error: 2.8925
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1723 - mean_absolute_error: 2.3420 - val_loss: 13.1374 - val_mean_absolute_error: 2.8503
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0020 - mean_absolute_error: 2.3239 - val_loss: 13.1659 - val_mean_absolute_error: 2.8588
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2301 - mean_absolute_error: 2.3439 - val_loss: 13.4759 - val_mean_absolute_error: 2.8924
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3496 - mean_absolute_error: 2.3583 - val_loss: 13.5652 - val_mean_absolute_error: 2.9034
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 739us/step
# CPU times: total: 3.58 s
# Wall time: 8.04 s

# %%
plt.plot(h0.history['val_loss'], color='blue')
plt.plot(h0.history['loss'], color='orange')
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['validation','training'])
plt.title('Adam')
plt.grid()
plt.show()

# %%
plt.plot(y_train, color='cyan')
plt.plot(p0.flatten(), color='magenta')
plt.ylabel('Temperature [degC]')
plt.xlabel('Hour')
plt.legend(['training','prediction'])
plt.title('Adam')
plt.grid()
plt.show()

# %%
#plt.plot(y_train, color='cyan')
#plt.plot(p0.flatten(), color='magenta')
#plt.ylabel('Temperature [degC]')
#plt.xlabel('Hour')
#plt.legend(['training','prediction'])
#plt.title('Adam (Final Year)')
#plt.grid()
#plt.xlim([60588,69348])
#plt.show()

# %%
#plt.plot(y_train, color='cyan')
#plt.plot(p0.flatten(), color='magenta')
#plt.ylabel('Temperature [degC]')
#plt.xlabel('Hour')
#plt.legend(['training','prediction'])
#plt.title('Adam (Final Month)')
#plt.grid()
#plt.xlim([68604,69348])
#plt.show()

# %%
#plt.plot(y_train, color='cyan')
#plt.plot(p0.flatten(), color='magenta')
#plt.ylabel('Temperature [degC]')
#plt.xlabel('Hour')
#plt.legend(['training','prediction'])
#plt.title('Adam (Final Week)')
#plt.grid()
#plt.xlim([69180,69348])
#plt.show()

# %%
plt.scatter(y_train,p0.flatten())
plt.ylabel('Estimated Temperature [degC]')
plt.xlabel('Measured Temperature [degC]')
plt.title('Adam')
plt.grid()
plt.ylim([-20,40])
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# ### Second Model, AdaGrad

# %%
# %%time
h1,p1=model_build('adagrad')
# Out:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 113.3795 - mean_absolute_error: 8.7282 - val_loss: 77.2385 - val_mean_absolute_error: 7.1546
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.2560 - mean_absolute_error: 5.2899 - val_loss: 52.2065 - val_mean_absolute_error: 5.7636
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.7026 - mean_absolute_error: 4.8173 - val_loss: 41.3045 - val_mean_absolute_error: 5.0826
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.0899 - mean_absolute_error: 4.5081 - val_loss: 33.8357 - val_mean_absolute_error: 4.5683
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.6618 - mean_absolute_error: 4.3590 - val_loss: 28.0901 - val_mean_absolute_error: 4.1592
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.0289 - mean_absolute_error: 4.2091 - val_loss: 24.9458 - val_mean_absolute_error: 3.9301
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.0374 - mean_absolute_error: 4.1468 - val_loss: 22.9868 - val_mean_absolute_error: 3.7866
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.0461 - mean_absolute_error: 3.9884 - val_loss: 21.5282 - val_mean_absolute_error: 3.6734
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25.7588 - mean_absolute_error: 3.9536 - val_loss: 20.7124 - val_mean_absolute_error: 3.6125
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.9163 - mean_absolute_error: 3.8979 - val_loss: 19.8665 - val_mean_absolute_error: 3.5437
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.1468 - mean_absolute_error: 3.8517 - val_loss: 19.3171 - val_mean_absolute_error: 3.5013
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.8617 - mean_absolute_error: 3.8149 - val_loss: 18.7853 - val_mean_absolute_error: 3.4540
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.2538 - mean_absolute_error: 3.7793 - val_loss: 18.4502 - val_mean_absolute_error: 3.4241
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.6027 - mean_absolute_error: 3.7274 - val_loss: 18.0232 - val_mean_absolute_error: 3.3777
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.9334 - mean_absolute_error: 3.7470 - val_loss: 17.6329 - val_mean_absolute_error: 3.3405
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.0238 - mean_absolute_error: 3.6658 - val_loss: 17.3860 - val_mean_absolute_error: 3.3148
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.7191 - mean_absolute_error: 3.6456 - val_loss: 17.2093 - val_mean_absolute_error: 3.3037
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.0222 - mean_absolute_error: 3.5753 - val_loss: 17.0043 - val_mean_absolute_error: 3.2753
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.1022 - mean_absolute_error: 3.5936 - val_loss: 16.6757 - val_mean_absolute_error: 3.2419
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.9778 - mean_absolute_error: 3.5795 - val_loss: 16.4185 - val_mean_absolute_error: 3.2161
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.3828 - mean_absolute_error: 3.5149 - val_loss: 16.3094 - val_mean_absolute_error: 3.2079
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.0986 - mean_absolute_error: 3.5104 - val_loss: 16.2049 - val_mean_absolute_error: 3.1967
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.8165 - mean_absolute_error: 3.4878 - val_loss: 16.0479 - val_mean_absolute_error: 3.1804
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.7090 - mean_absolute_error: 3.4639 - val_loss: 15.8769 - val_mean_absolute_error: 3.1609
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.5617 - mean_absolute_error: 3.4580 - val_loss: 15.7921 - val_mean_absolute_error: 3.1534
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.0142 - mean_absolute_error: 3.4182 - val_loss: 15.6603 - val_mean_absolute_error: 3.1366
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.0912 - mean_absolute_error: 3.4038 - val_loss: 15.4812 - val_mean_absolute_error: 3.1200
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.3711 - mean_absolute_error: 3.4232 - val_loss: 15.4063 - val_mean_absolute_error: 3.1126
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.9582 - mean_absolute_error: 3.3951 - val_loss: 15.2519 - val_mean_absolute_error: 3.0918
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.5816 - mean_absolute_error: 3.3753 - val_loss: 15.1100 - val_mean_absolute_error: 3.0786
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.0724 - mean_absolute_error: 3.3881 - val_loss: 15.1237 - val_mean_absolute_error: 3.0836
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.5032 - mean_absolute_error: 3.3568 - val_loss: 14.9380 - val_mean_absolute_error: 3.0601
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 750us/step
# CPU times: total: 3.33 s
# Wall time: 7.2 s

# %%
plt.plot(h0.history['val_loss'], color='blue')
plt.plot(h1.history['val_loss'], color='orange',marker='o')
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['Adam','AdaGrad'])
plt.title('No Breath-Holding')
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Impsum
# ### Third Model, Stochastic Gradient Descent with Nesterov Momentum

# %%
opt012=tf.keras.optimizers.SGD(momentum=0.5,
                               nesterov=True,
                               name='nSGD'
                              )

# %%
# %%time
h2,p2=model_build(opt012)
# Out:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 846us/step
# CPU times: total: 3.5 s
# Wall time: 7.92 s

# %%
plt.plot(h0.history['val_loss'],color='blue')
plt.plot(h1.history['val_loss'],color='orange',marker='o')
plt.plot(h2.history['val_loss'],color='cyan',marker='x')
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['Adam','AdaGrad','SGD+Nest'])
plt.title('Missing in Action')
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Impsum
# ### Fourth Model, Root Mean Squared Propagation

# %%
# %%time
h3,p3=model_build('rmsprop')
# Out:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 57.0769 - mean_absolute_error: 5.7214 - val_loss: 16.6410 - val_mean_absolute_error: 3.2742
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.2514 - mean_absolute_error: 3.5150 - val_loss: 14.8736 - val_mean_absolute_error: 3.0943
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.6700 - mean_absolute_error: 3.2826 - val_loss: 15.1476 - val_mean_absolute_error: 3.1299
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.0107 - mean_absolute_error: 3.1362 - val_loss: 13.7074 - val_mean_absolute_error: 2.9412
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.5628 - mean_absolute_error: 3.0815 - val_loss: 15.4284 - val_mean_absolute_error: 3.0787
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.1829 - mean_absolute_error: 3.0307 - val_loss: 14.6787 - val_mean_absolute_error: 3.0247
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.0590 - mean_absolute_error: 2.9060 - val_loss: 13.0758 - val_mean_absolute_error: 2.9072
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.3053 - mean_absolute_error: 2.9429 - val_loss: 16.6668 - val_mean_absolute_error: 3.2116
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.0114 - mean_absolute_error: 2.9070 - val_loss: 12.4892 - val_mean_absolute_error: 2.8114
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.0999 - mean_absolute_error: 2.8083 - val_loss: 12.9409 - val_mean_absolute_error: 2.8496
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.5746 - mean_absolute_error: 2.7526 - val_loss: 17.3635 - val_mean_absolute_error: 3.2714
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.7968 - mean_absolute_error: 2.7581 - val_loss: 12.5753 - val_mean_absolute_error: 2.7851
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.8210 - mean_absolute_error: 2.6736 - val_loss: 16.9531 - val_mean_absolute_error: 3.2426
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.4146 - mean_absolute_error: 2.7233 - val_loss: 13.6056 - val_mean_absolute_error: 2.9361
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.6662 - mean_absolute_error: 2.6354 - val_loss: 18.3390 - val_mean_absolute_error: 3.3870
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.3851 - mean_absolute_error: 2.7026 - val_loss: 14.8855 - val_mean_absolute_error: 3.0375
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.4366 - mean_absolute_error: 2.6132 - val_loss: 14.5004 - val_mean_absolute_error: 2.9992
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.1244 - mean_absolute_error: 2.5713 - val_loss: 12.8722 - val_mean_absolute_error: 2.8320
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.9667 - mean_absolute_error: 2.5546 - val_loss: 15.0671 - val_mean_absolute_error: 3.0534
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2914 - mean_absolute_error: 2.5941 - val_loss: 13.3627 - val_mean_absolute_error: 2.8719
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.0164 - mean_absolute_error: 2.5518 - val_loss: 14.0766 - val_mean_absolute_error: 2.9397
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.0567 - mean_absolute_error: 2.5596 - val_loss: 14.7788 - val_mean_absolute_error: 3.0242
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.7238 - mean_absolute_error: 2.5291 - val_loss: 15.0163 - val_mean_absolute_error: 3.0432
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5702 - mean_absolute_error: 2.4982 - val_loss: 17.0989 - val_mean_absolute_error: 3.2778
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.7943 - mean_absolute_error: 2.5338 - val_loss: 12.8715 - val_mean_absolute_error: 2.8349
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5451 - mean_absolute_error: 2.5084 - val_loss: 12.7465 - val_mean_absolute_error: 2.8197
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.1989 - mean_absolute_error: 2.4642 - val_loss: 14.0869 - val_mean_absolute_error: 2.9522
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.1794 - mean_absolute_error: 2.4651 - val_loss: 12.9018 - val_mean_absolute_error: 2.8402
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9886 - mean_absolute_error: 2.4222 - val_loss: 16.7820 - val_mean_absolute_error: 3.2484
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7446 - mean_absolute_error: 2.3975 - val_loss: 13.4023 - val_mean_absolute_error: 2.9010
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6722 - mean_absolute_error: 2.3998 - val_loss: 13.2949 - val_mean_absolute_error: 2.8688
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9018 - mean_absolute_error: 2.4131 - val_loss: 13.4273 - val_mean_absolute_error: 2.8858
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 838us/step
# CPU times: total: 3.77 s
# Wall time: 8.15 s

# %%
plt.plot(h0.history['val_loss'],color='blue')
plt.plot(h1.history['val_loss'],color='orange',marker='o')
plt.plot(h2.history['val_loss'],color='cyan',marker='x')
plt.plot(h3.history['val_loss'],color='magenta',marker='s')
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['Adam','AdaGrad','SGD+Nest','RMSProp'])
plt.title('We\'re Rooting For You')
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_loss'],color='blue')
plt.plot(h1.history['val_loss'],color='orange',marker='o')
plt.plot(h2.history['val_loss'],color='cyan',marker='x')
plt.plot(h3.history['val_loss'],color='magenta',marker='s')
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['Adam','AdaGrad','SGD+Nest','RMSProp'])
plt.title('Photo Finish?')
plt.ylim([10,20])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# # Conclusions
# Blah blah blah
