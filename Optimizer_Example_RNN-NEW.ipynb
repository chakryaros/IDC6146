# %% [markdown]
# # Optimizer Example
# MNIST RNN example showing comparison between*newer* optimizers.
#
# Richard Henry, 15-Jul-2024

# %%
#Import Libararies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# Test Libraries

# %%
# Check python version
from platform import python_version
print(python_version())
#3.12.3
# Out:
# 3.12.3

# %%
# Check tensorflow version
tf.__version__
#2.16.1
# Out:
# '2.16.2'

# %%
# Check keras version
tf.keras.__version__
#3.4.1
# Out:
# '3.4.1'

# %% [markdown]
# # Optimizer List

# %% [markdown]
# ## AdaDelta
# Adadelta optimization is a stochastic gradient descent method that is based on adaptive learning rate per dimension to address two drawbacks:
#
# - The continual decay of learning rates throughout training.
# - The need for a manually selected global learning rate.
#
# Adadelta is a more robust extension of Adagrad that adapts learning rates based on a moving window of gradient updates, instead of accumulating all past gradients. This way, Adadelta continues learning even when many updates have been done. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2012|
# |Short Cut|'adadelta'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adadelta

# %%
opt001=tf.keras.optimizers.Adadelta(
    learning_rate=0.001,
    rho=0.95,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adadelta'
)

# %% [markdown]
# ## AdaFactor
# Adafactor is commonly used in NLP tasks, and has the advantage of taking less memory because it only saves partial information of previous gradients. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2018|
# |Short Cut|'adafactor'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adafactor

# %%
opt002=tf.keras.optimizers.Adafactor(
    learning_rate=0.001,
    beta_2_decay=-0.8,
    epsilon_1=1e-30,
    epsilon_2=0.001,
    clip_threshold=1.0,
    relative_step=True,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adafactor'
)

# %% [markdown]
# ## AdaGrad
# Adagrad is an optimizer with parameter-specific learning rates, which are adapted relative to how frequently a parameter gets updated during training. The more updates a parameter receives, the smaller the updates. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2011|
# |Short Cut|'adagrad'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adagrad

# %%
opt003=tf.keras.optimizers.Adagrad(
    learning_rate=0.001,
    initial_accumulator_value=0.1,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adagrad'
)

# %% [markdown]
# ## ADAM
# Adam optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|duh|
# |Year|2015|
# |Short Cut|'adam'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam

# %%
opt000=tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adam'
)

# %% [markdown]
# ## ADAM with Weight Decay
# AdamW optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments with an added method to decay weights. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2019|
# |Short Cut|'adamw'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/AdamW

# %%
opt004=tf.keras.optimizers.AdamW(
    learning_rate=0.001,
    weight_decay=0.004,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adamw'
)

# %% [markdown]
# ## AdaMax
# A variant of Adam described in the same paper and based on the infinity norm, is a first-order gradient-based optimization method. Due to its capability of adjusting the learning rate based on data characteristics, it is suited to learn time-variant process, e.g., speech data with dynamically changed noise conditions. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2015|
# |Short Cut|'adamax'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adamax

# %%
opt005=tf.keras.optimizers.Adamax(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adamax'
)

# %% [markdown]
# ## Follow the Regularized Leader
# An optimization algorithm developed at Google for click-through rate prediction. It is most suitable for shallow models with large and sparse feature spaces. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2013|
# |Short Cut|'ftrl'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Ftrl

# %%
opt006=tf.keras.optimizers.Ftrl(
    learning_rate=0.001,
    learning_rate_power=-0.5,
    initial_accumulator_value=0.1,
    l1_regularization_strength=0.0,
    l2_regularization_strength=0.0,
    l2_shrinkage_regularization_strength=0.0,
    beta=0.0,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='ftrl'
)

# %% [markdown]
# ## Lion
# A stochastic-gradient-descent method that uses the sign operator to control the magnitude of the update, unlike other adaptive optimizers such as Adam that rely on second-order moments. This make Lion more memory-efficient as it only keeps track of the momentum. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Hell No|
# |Year|2023|
# |Short Cut|'lion'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Lion

# %%
opt007=tf.keras.optimizers.Lion(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.99,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='lion'
)

# %% [markdown]
# ## Adam with Nesterov momentum
#
# Momentum is an approach that accelerates the progress of the search to skim across flat areas and smooth out bouncy gradients. [Brownlee]
# Nesterov momentum is an extension of momentum that involves calculating the decaying moving average of the gradients of projected positions in the search space rather than the actual positions themselves. [Also Brownlee]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2015|
# |Short Cut|'nadam'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam

# %%
opt008=tf.keras.optimizers.Nadam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='nadam'
)

# %% [markdown]
# ## Root Mean Square Propagation
# ADAM is an extension of this.
#
# The gist of RMSprop is to:
#
# - Maintain a moving (discounted) average of the square of gradients
# - Divide the gradient by the root of this average
#
# [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yup|
# |Year|2012|
# |Short Cut|'rmsprop'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/RMSprop

# %%
opt009=tf.keras.optimizers.RMSprop(
    learning_rate=0.001,
    rho=0.9,
    momentum=0.0,
    epsilon=1e-07,
    centered=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='rmsprop'
)

# %% [markdown]
# ## Stochastic Gradient Descent
# Gradient descent is an optimization algorithm that follows the negative gradient of an objective function in order to locate the minimum of the function. [Brownlee] Instead of updating weights based on the sum of the accumulated errors over all training examples, we update parameters incrementally for each training example. Although SGD can be considered an approximation of gradient descent, it typically reaches convergence faster because of more frequent weight updates.[Raschka]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'SGD'<-- notice CAPS!|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD

# %%
opt010=tf.keras.optimizers.SGD(
    learning_rate=0.01,
    momentum=0.0,
    nesterov=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='SGD'
)

# %% [markdown]
# ## SGD with Momentum
# Increase `momentum` above zero and below unity. Not sure it is used.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'mSGD'|
# |Default Setting|No|

# %%
opt011=tf.keras.optimizers.SGD(momentum=0.5,
                               name='mSGD'
                              )

# %% [markdown]
# ## SGD with Nesterov Momentum
# Increase `momentum` above zero and below unity. Set `nesterov` to `True`.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'nSGD'|
# |Default Setting|No|

# %%
opt012=tf.keras.optimizers.SGD(momentum=0.5,
                               nesterov=True,
                               name='nSGD'
                              )

# %% [markdown]
# ## RMSprop with Momentum
# Increase `momentum` above zero and below unity.  Notice we can't use Nesterov here.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|who knows|
# |Short Cut|'nRMS'|
# |Default Setting|No|

# %%
opt013=tf.keras.optimizers.RMSprop(momentum=0.5,
                                   name='nRMS'
                                  )

# %% [markdown]
# ## Natural Gradient Descent
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Unfortunately, yes|
# |Year|1998|
# |Short Cut|'NGD'|
# |Default Setting|No clue|
#
# Can we like, ignore this one?
#
# https://www.geeksforgeeks.org/optimizers-in-tensorflow/

# %%
opt999=tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.001,
                                                    use_locking=True,
                                                    name = 'NGD')
# Out:
# WARNING:tensorflow:From C:\Users\brera\AppData\Local\Temp\ipykernel_26872\1278675782.py:1: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %% [markdown]
# ## Unavailable
# Optimizers mentioned in the article but not available in tensorflow 2
#
# - vSGD (Schaul et al, 2012)
#
# - natural Newton (Roux & Fitzgibbon, 2012)
#
# - SFO (Sohl & Dickstein, 2014)

# %% [markdown]
# # MNIST RNN
# Here we examine optimizers that appeared *after* Adam.
#
# Adapted from Keras Documentation (via Kaggle).
# https://www.kaggle.com/code/ankan1998/image-classification-with-recurrent-neural-network

# %%
# Model / data parameters
num_classes = 10
input_shape = (28,28)
batch_size = 64
num_epochs = 15

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28)
#x_train = np.expand_dims(x_train, -1)
#x_test = np.expand_dims(x_test, -1)
# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# Build & train model function
def model_build(myOpti,   #Optimizer
                myClas,   #Number of Outputs
                myShap,   #Input Array Shape
                myBatc,   #Batch Size
                myEpoc,   #Number of Epochs
                myxTra,   #x_train
                myyTra,   #y_train
                myxTes,   #x_test
                myyTes):  #y_test
    #Build it exactly the same every time
    tf.random.set_seed(19)
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape=myShap),
            #tf.keras.layers.Rescaling(1.0/255),
            tf.keras.layers.SimpleRNN(128),
            tf.keras.layers.Dense(128,
                           activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(myClas,
                                  activation="softmax"),
        ]
    )
    model.compile(loss="categorical_crossentropy",
                  optimizer=myOpti,
                  metrics=["accuracy"])
    myHis=model.fit(myxTra,
                    myyTra,
                    batch_size=myBatc,
                    epochs=myEpoc,
                    validation_split=0.1)
    score = model.evaluate(myxTes,
                           myyTes,
                           verbose=0)
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])
    return myHis

# %% [markdown]
# ### First Model, LION

# %%
# %%time
h0=model_build('lion',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7762 - loss: 0.7047 - val_accuracy: 0.8522 - val_loss: 0.5028
# Epoch 2/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7782 - loss: 0.7404 - val_accuracy: 0.7798 - val_loss: 0.6822
# Epoch 3/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5547 - loss: 1.2910 - val_accuracy: 0.3813 - val_loss: 1.5991
# Epoch 4/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3981 - loss: 1.5462 - val_accuracy: 0.5045 - val_loss: 1.2708
# Epoch 5/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4477 - loss: 1.4439 - val_accuracy: 0.4922 - val_loss: 1.3311
# Epoch 6/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4363 - loss: 1.4589 - val_accuracy: 0.4365 - val_loss: 1.3531
# Epoch 7/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4138 - loss: 1.4689 - val_accuracy: 0.4380 - val_loss: 1.3315
# Epoch 8/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3903 - loss: 1.5548 - val_accuracy: 0.3182 - val_loss: 1.7127
# Epoch 9/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3203 - loss: 1.7886 - val_accuracy: 0.3213 - val_loss: 1.6642
# Epoch 10/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3108 - loss: 1.8015 - val_accuracy: 0.2233 - val_loss: 1.9644
# Epoch 11/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.1840 - loss: 2.1625 - val_accuracy: 0.1050 - val_loss: 2.3029
# Epoch 12/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.1149 - loss: 2.3016 - val_accuracy: 0.1050 - val_loss: 2.3023
# Epoch 13/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.1149 - loss: 2.3016 - val_accuracy: 0.1050 - val_loss: 2.3023
# Epoch 14/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.1119 - loss: 2203.6621 - val_accuracy: 0.1563 - val_loss: 2422.5876
# Epoch 15/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.1154 - loss: 3956.0815 - val_accuracy: 0.0665 - val_loss: 276.0429
# Test loss: 256.214599609375
# Test accuracy: 0.07559999823570251
# CPU times: total: 26.9 s
# Wall time: 1min 4s

# %%
plt.plot(h0.history['val_loss'], color='blue')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['LION'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['LION'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# ### Second Model, AdaFactor

# %%
# %%time
h1=model_build('adafactor',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5669 - loss: 1.3933 - val_accuracy: 0.9090 - val_loss: 0.3426
# Epoch 2/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8762 - loss: 0.4103 - val_accuracy: 0.9363 - val_loss: 0.2210
# Epoch 3/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9116 - loss: 0.2941 - val_accuracy: 0.9480 - val_loss: 0.1767
# Epoch 4/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9270 - loss: 0.2394 - val_accuracy: 0.9558 - val_loss: 0.1494
# Epoch 5/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9369 - loss: 0.2084 - val_accuracy: 0.9608 - val_loss: 0.1331
# Epoch 6/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9424 - loss: 0.1834 - val_accuracy: 0.9650 - val_loss: 0.1193
# Epoch 7/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9486 - loss: 0.1686 - val_accuracy: 0.9660 - val_loss: 0.1105
# Epoch 8/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9531 - loss: 0.1518 - val_accuracy: 0.9687 - val_loss: 0.1027
# Epoch 9/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9565 - loss: 0.1421 - val_accuracy: 0.9685 - val_loss: 0.1002
# Epoch 10/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9593 - loss: 0.1330 - val_accuracy: 0.9705 - val_loss: 0.0987
# Epoch 11/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9617 - loss: 0.1252 - val_accuracy: 0.9697 - val_loss: 0.1010
# Epoch 12/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9646 - loss: 0.1181 - val_accuracy: 0.9710 - val_loss: 0.0953
# Epoch 13/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9648 - loss: 0.1146 - val_accuracy: 0.9713 - val_loss: 0.0995
# Epoch 14/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9675 - loss: 0.1074 - val_accuracy: 0.9725 - val_loss: 0.0974
# Epoch 15/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9691 - loss: 0.1026 - val_accuracy: 0.9727 - val_loss: 0.0947
# Test loss: 0.11333922296762466
# Test accuracy: 0.9648000001907349
# CPU times: total: 31.7 s
# Wall time: 1min 10s

# %%
plt.plot(h0.history['val_loss'], color='blue')
plt.plot(h1.history['val_loss'], color='orange',marker='o')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['LION','Adafactor'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue')
plt.plot(h1.history['val_accuracy'],color='orange',marker='o')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Impsum
# ### Third Model, Adam + Weight Decay

# %%
# %%time
h2=model_build('adamw',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.7897 - loss: 0.6752 - val_accuracy: 0.9583 - val_loss: 0.1443
# Epoch 2/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9333 - loss: 0.2244 - val_accuracy: 0.9637 - val_loss: 0.1330
# Epoch 3/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9471 - loss: 0.1781 - val_accuracy: 0.9582 - val_loss: 0.1456
# Epoch 4/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9547 - loss: 0.1571 - val_accuracy: 0.9703 - val_loss: 0.1011
# Epoch 5/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9588 - loss: 0.1445 - val_accuracy: 0.9717 - val_loss: 0.1050
# Epoch 6/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9637 - loss: 0.1323 - val_accuracy: 0.9720 - val_loss: 0.1069
# Epoch 7/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9649 - loss: 0.1234 - val_accuracy: 0.9755 - val_loss: 0.0915
# Epoch 8/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9661 - loss: 0.1156 - val_accuracy: 0.9733 - val_loss: 0.1028
# Epoch 9/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9669 - loss: 0.1183 - val_accuracy: 0.9725 - val_loss: 0.0992
# Epoch 10/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9675 - loss: 0.1121 - val_accuracy: 0.9703 - val_loss: 0.1119
# Epoch 11/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9718 - loss: 0.0996 - val_accuracy: 0.9717 - val_loss: 0.1067
# Epoch 12/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9695 - loss: 0.1058 - val_accuracy: 0.9740 - val_loss: 0.0936
# Epoch 13/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9703 - loss: 0.1028 - val_accuracy: 0.9732 - val_loss: 0.0936
# Epoch 14/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9729 - loss: 0.0962 - val_accuracy: 0.9723 - val_loss: 0.1012
# Epoch 15/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9737 - loss: 0.0883 - val_accuracy: 0.9778 - val_loss: 0.0926
# Test loss: 0.10497043281793594
# Test accuracy: 0.9724000096321106
# CPU times: total: 33.4 s
# Wall time: 1min 25s

# %%
plt.plot(h0.history['val_loss'],color='blue')
plt.plot(h1.history['val_loss'],color='orange',marker='o')
plt.plot(h2.history['val_loss'],color='cyan',marker='x')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor','Adam+Wgt'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue')
plt.plot(h1.history['val_accuracy'],color='orange',marker='o')
plt.plot(h2.history['val_accuracy'],color='cyan',marker='x')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor','Adam+Wgt'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Impsum
# ### Fourth Model, ADAM

# %%
# %%time
h3=model_build('adam',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.7897 - loss: 0.6640 - val_accuracy: 0.9558 - val_loss: 0.1503
# Epoch 2/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9362 - loss: 0.2166 - val_accuracy: 0.9640 - val_loss: 0.1235
# Epoch 3/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9500 - loss: 0.1680 - val_accuracy: 0.9663 - val_loss: 0.1118
# Epoch 4/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9561 - loss: 0.1525 - val_accuracy: 0.9702 - val_loss: 0.1037
# Epoch 5/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9587 - loss: 0.1401 - val_accuracy: 0.9663 - val_loss: 0.1238
# Epoch 6/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9628 - loss: 0.1259 - val_accuracy: 0.9707 - val_loss: 0.1034
# Epoch 7/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9633 - loss: 0.1256 - val_accuracy: 0.9743 - val_loss: 0.0902
# Epoch 8/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9683 - loss: 0.1079 - val_accuracy: 0.9728 - val_loss: 0.1011
# Epoch 9/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9661 - loss: 0.1191 - val_accuracy: 0.9732 - val_loss: 0.0914
# Epoch 10/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9720 - loss: 0.0998 - val_accuracy: 0.9750 - val_loss: 0.0881
# Epoch 11/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9698 - loss: 0.1035 - val_accuracy: 0.9718 - val_loss: 0.0946
# Epoch 12/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9718 - loss: 0.0969 - val_accuracy: 0.9760 - val_loss: 0.0848
# Epoch 13/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9727 - loss: 0.0968 - val_accuracy: 0.9692 - val_loss: 0.1022
# Epoch 14/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9724 - loss: 0.0961 - val_accuracy: 0.9708 - val_loss: 0.1012
# Epoch 15/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9749 - loss: 0.0887 - val_accuracy: 0.9737 - val_loss: 0.0968
# Test loss: 0.11176600307226181
# Test accuracy: 0.9699000120162964
# CPU times: total: 32.9 s
# Wall time: 1min 26s

# %%
plt.plot(h0.history['val_loss'],color='blue')
plt.plot(h1.history['val_loss'],color='orange',marker='o')
plt.plot(h2.history['val_loss'],color='cyan',marker='x')
plt.plot(h3.history['val_loss'],color='pink',marker='s')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor','Adam+Wgt','Adam'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue')
plt.plot(h1.history['val_accuracy'],color='orange',marker='o')
plt.plot(h2.history['val_accuracy'],color='cyan',marker='x')
plt.plot(h3.history['val_accuracy'],color='pink',marker='s')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor','Adam+Wgt','Adam'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# # Conclusions
# Blah blah blah
