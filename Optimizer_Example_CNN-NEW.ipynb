# %% [markdown]
# # Optimizer Example
# MNIST CNN example showing comparison between *newer* optimizers.
#
# Richard Henry, 15-Jul-2024

# %%
#Import Libararies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# Test Libraries

# %%
# Check python version
from platform import python_version
print(python_version())
#3.12.3
# Out:
# 3.12.3

# %%
# Check tensorflow version
tf.__version__
#2.16.1
# Out:
# '2.16.2'

# %%
# Check keras version
tf.keras.__version__
#3.4.1
# Out:
# '3.4.1'

# %% [markdown]
# # Optimizer List

# %% [markdown]
# ## AdaDelta
# Adadelta optimization is a stochastic gradient descent method that is based on adaptive learning rate per dimension to address two drawbacks:
#
# - The continual decay of learning rates throughout training.
# - The need for a manually selected global learning rate.
#
# Adadelta is a more robust extension of Adagrad that adapts learning rates based on a moving window of gradient updates, instead of accumulating all past gradients. This way, Adadelta continues learning even when many updates have been done. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2012|
# |Short Cut|'adadelta'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adadelta

# %%
opt001=tf.keras.optimizers.Adadelta(
    learning_rate=0.001,
    rho=0.95,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adadelta'
)

# %% [markdown]
# ## AdaFactor
# Adafactor is commonly used in NLP tasks, and has the advantage of taking less memory because it only saves partial information of previous gradients. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2018|
# |Short Cut|'adafactor'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adafactor

# %%
opt002=tf.keras.optimizers.Adafactor(
    learning_rate=0.001,
    beta_2_decay=-0.8,
    epsilon_1=1e-30,
    epsilon_2=0.001,
    clip_threshold=1.0,
    relative_step=True,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adafactor'
)

# %% [markdown]
# ## AdaGrad
# Adagrad is an optimizer with parameter-specific learning rates, which are adapted relative to how frequently a parameter gets updated during training. The more updates a parameter receives, the smaller the updates. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2011|
# |Short Cut|'adagrad'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adagrad

# %%
opt003=tf.keras.optimizers.Adagrad(
    learning_rate=0.001,
    initial_accumulator_value=0.1,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adagrad'
)

# %% [markdown]
# ## ADAM
# Adam optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|duh|
# |Year|2015|
# |Short Cut|'adam'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam

# %%
opt000=tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adam'
)

# %% [markdown]
# ## ADAM with Weight Decay
# AdamW optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments with an added method to decay weights. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2019|
# |Short Cut|'adamw'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/AdamW

# %%
opt004=tf.keras.optimizers.AdamW(
    learning_rate=0.001,
    weight_decay=0.004,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adamw'
)

# %% [markdown]
# ## AdaMax
# A variant of Adam described in the same paper and based on the infinity norm, is a first-order gradient-based optimization method. Due to its capability of adjusting the learning rate based on data characteristics, it is suited to learn time-variant process, e.g., speech data with dynamically changed noise conditions. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2015|
# |Short Cut|'adamax'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adamax

# %%
opt005=tf.keras.optimizers.Adamax(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adamax'
)

# %% [markdown]
# ## Follow the Regularized Leader
# An optimization algorithm developed at Google for click-through rate prediction. It is most suitable for shallow models with large and sparse feature spaces. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2013|
# |Short Cut|'ftrl'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Ftrl

# %%
opt006=tf.keras.optimizers.Ftrl(
    learning_rate=0.001,
    learning_rate_power=-0.5,
    initial_accumulator_value=0.1,
    l1_regularization_strength=0.0,
    l2_regularization_strength=0.0,
    l2_shrinkage_regularization_strength=0.0,
    beta=0.0,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='ftrl'
)

# %% [markdown]
# ## Lion
# A stochastic-gradient-descent method that uses the sign operator to control the magnitude of the update, unlike other adaptive optimizers such as Adam that rely on second-order moments. This make Lion more memory-efficient as it only keeps track of the momentum. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Hell No|
# |Year|2023|
# |Short Cut|'lion'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Lion

# %%
opt007=tf.keras.optimizers.Lion(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.99,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='lion'
)

# %% [markdown]
# ## Adam with Nesterov Momentum
#
# Momentum is an approach that accelerates the progress of the search to skim across flat areas and smooth out bouncy gradients. [Brownlee]
# Nesterov momentum is an extension of momentum that involves calculating the decaying moving average of the gradients of projected positions in the search space rather than the actual positions themselves. [Also Brownlee]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2015|
# |Short Cut|'nadam'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam

# %%
opt008=tf.keras.optimizers.Nadam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='nadam'
)

# %% [markdown]
# ## Root Mean Square Propagation
# ADAM is an extension of this.
#
# The gist of RMSprop is to:
#
# - Maintain a moving (discounted) average of the square of gradients
# - Divide the gradient by the root of this average
#
# [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yup|
# |Year|2012|
# |Short Cut|'rmsprop'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/RMSprop

# %%
opt009=tf.keras.optimizers.RMSprop(
    learning_rate=0.001,
    rho=0.9,
    momentum=0.0,
    epsilon=1e-07,
    centered=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='rmsprop'
)

# %% [markdown]
# ## Stochastic Gradient Descent
# Gradient descent is an optimization algorithm that follows the negative gradient of an objective function in order to locate the minimum of the function. [Brownlee] Instead of updating weights based on the sum of the accumulated errors over all training examples, we update parameters incrementally for each training example. Although SGD can be considered an approximation of gradient descent, it typically reaches convergence faster because of more frequent weight updates.[Raschka]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'SGD'<-- notice CAPS!|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD

# %%
opt010=tf.keras.optimizers.SGD(
    learning_rate=0.01,
    momentum=0.0,
    nesterov=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='SGD'
)

# %% [markdown]
# ## SGD with Momentum
# Increase `momentum` above zero and below unity. Not sure it is used.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'mSGD'|
# |Default Setting|No|

# %%
opt011=tf.keras.optimizers.SGD(momentum=0.5,
                               name='mSGD'
                              )

# %% [markdown]
# ## SGD with Nesterov Momentum
# Increase `momentum` above zero and below unity. Set `nesterov` to `True`.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'nSGD'|
# |Default Setting|No|

# %%
opt012=tf.keras.optimizers.SGD(momentum=0.5,
                               nesterov=True,
                               name='nSGD'
                              )

# %% [markdown]
# ## RMSprop with Momentum
# Increase `momentum` above zero and below unity.  Notice we can't use Nesterov here.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|who knows|
# |Short Cut|'nRMS'|
# |Default Setting|No|

# %%
opt013=tf.keras.optimizers.RMSprop(momentum=0.5,
                                   name='nRMS'
                                  )

# %% [markdown]
# ## Natural Gradient Descent
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Unfortunately, yes|
# |Year|1998|
# |Short Cut|'NGD'|
# |Default Setting|No clue|
#
# Can we like, ignore this one?
#
# https://www.geeksforgeeks.org/optimizers-in-tensorflow/

# %%
opt999=tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.001, 
                                                    use_locking=True,
                                                    name = 'NGD')
# Out:
# WARNING:tensorflow:From C:\Users\brera\AppData\Local\Temp\ipykernel_16772\2360995615.py:1: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %% [markdown]
# ## Unavailable
# Optimizers mentioned in the article but not available in tensorflow 2
#
# - vSGD (Schaul et al, 2012)
#
# - natural Newton (Roux & Fitzgibbon, 2012)
#
# - SFO (Sohl & Dickstein, 2014)

# %% [markdown]
# # MNIST CNN
# Here we are looking at optimizers that appeared *after* Adam.
#
# Adapted from Keras Documentation.
# https://keras.io/examples/vision/mnist_convnet/

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)
batch_size = 128
num_epochs = 15

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# Build & train model function
def model_build(myOpti,
                myClas,
                myShap,
                myBatc,
                myEpoc,
                myxTra,
                myyTra,
                myxTes,
                myyTes):
    #Build it exactly the same every time
    tf.random.set_seed(19) 
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape=myShap),
            #tf.keras.layers.Rescaling(1.0/255),
            tf.keras.layers.Conv2D(32, 
                                   kernel_size=(3, 3), 
                                   activation="relu"),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Conv2D(64, 
                                   kernel_size=(3, 3), 
                                   activation="relu"),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(myClas, 
                                  activation="softmax"),
        ]
    )
    model.compile(loss="categorical_crossentropy", 
                  optimizer=myOpti, 
                  metrics=["accuracy"])
    myHis=model.fit(myxTra, 
                    myyTra, 
                    batch_size=myBatc, 
                    epochs=myEpoc, 
                    validation_split=0.1)
    score = model.evaluate(myxTes, 
                           myyTes, 
                           verbose=0)
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])
    return myHis

# %% [markdown]
# ### First Model, LION

# %%
# %%time
h0=model_build('lion',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.7843 - loss: 0.7205 - val_accuracy: 0.9855 - val_loss: 0.0520
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9714 - loss: 0.0937 - val_accuracy: 0.9880 - val_loss: 0.0405
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9766 - loss: 0.0739 - val_accuracy: 0.9890 - val_loss: 0.0355
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9801 - loss: 0.0630 - val_accuracy: 0.9902 - val_loss: 0.0355
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9809 - loss: 0.0626 - val_accuracy: 0.9902 - val_loss: 0.0347
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9822 - loss: 0.0576 - val_accuracy: 0.9913 - val_loss: 0.0360
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9820 - loss: 0.0561 - val_accuracy: 0.9898 - val_loss: 0.0345
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9842 - loss: 0.0507 - val_accuracy: 0.9912 - val_loss: 0.0362
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9826 - loss: 0.0527 - val_accuracy: 0.9908 - val_loss: 0.0340
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9837 - loss: 0.0530 - val_accuracy: 0.9902 - val_loss: 0.0377
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9846 - loss: 0.0501 - val_accuracy: 0.9903 - val_loss: 0.0362
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9843 - loss: 0.0504 - val_accuracy: 0.9900 - val_loss: 0.0390
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9840 - loss: 0.0504 - val_accuracy: 0.9907 - val_loss: 0.0373
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9849 - loss: 0.0502 - val_accuracy: 0.9890 - val_loss: 0.0392
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9856 - loss: 0.0481 - val_accuracy: 0.9902 - val_loss: 0.0400
# Test loss: 0.03619075566530228
# Test accuracy: 0.9894000291824341
# CPU times: total: 56.6 s
# Wall time: 1min 14s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['LION'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['LION'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# ### Second Model, AdaFactor

# %%
# %%time
h1=model_build('adafactor',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2649 - loss: 2.1776 - val_accuracy: 0.8040 - val_loss: 1.3668
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.6590 - loss: 1.2302 - val_accuracy: 0.8963 - val_loss: 0.4937
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.7970 - loss: 0.6505 - val_accuracy: 0.9288 - val_loss: 0.2955
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8593 - loss: 0.4537 - val_accuracy: 0.9455 - val_loss: 0.2187
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8879 - loss: 0.3643 - val_accuracy: 0.9572 - val_loss: 0.1773
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9072 - loss: 0.3011 - val_accuracy: 0.9618 - val_loss: 0.1523
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9210 - loss: 0.2599 - val_accuracy: 0.9658 - val_loss: 0.1341
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9269 - loss: 0.2343 - val_accuracy: 0.9692 - val_loss: 0.1215
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9357 - loss: 0.2081 - val_accuracy: 0.9715 - val_loss: 0.1107
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9405 - loss: 0.1943 - val_accuracy: 0.9742 - val_loss: 0.1028
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9440 - loss: 0.1794 - val_accuracy: 0.9758 - val_loss: 0.0963
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9483 - loss: 0.1651 - val_accuracy: 0.9767 - val_loss: 0.0907
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9516 - loss: 0.1562 - val_accuracy: 0.9782 - val_loss: 0.0852
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9553 - loss: 0.1482 - val_accuracy: 0.9785 - val_loss: 0.0811
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9572 - loss: 0.1380 - val_accuracy: 0.9793 - val_loss: 0.0777
# Test loss: 0.08366040885448456
# Test accuracy: 0.9746999740600586
# CPU times: total: 1min 5s
# Wall time: 1min 34s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.plot(h1.history['val_accuracy'],color='orange',linestyle='solid')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Impsum
# ### Third Model, Adam with Weight Decay

# %%
# %%time
h2=model_build('adamw',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.7746 - loss: 0.7380 - val_accuracy: 0.9783 - val_loss: 0.0824
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9627 - loss: 0.1237 - val_accuracy: 0.9847 - val_loss: 0.0570
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9718 - loss: 0.0904 - val_accuracy: 0.9850 - val_loss: 0.0496
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9758 - loss: 0.0771 - val_accuracy: 0.9875 - val_loss: 0.0430
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9799 - loss: 0.0652 - val_accuracy: 0.9885 - val_loss: 0.0399
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9817 - loss: 0.0577 - val_accuracy: 0.9897 - val_loss: 0.0388
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9833 - loss: 0.0530 - val_accuracy: 0.9888 - val_loss: 0.0367
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9836 - loss: 0.0509 - val_accuracy: 0.9887 - val_loss: 0.0358
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9850 - loss: 0.0456 - val_accuracy: 0.9888 - val_loss: 0.0349
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9859 - loss: 0.0438 - val_accuracy: 0.9900 - val_loss: 0.0331
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9872 - loss: 0.0407 - val_accuracy: 0.9912 - val_loss: 0.0321
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9877 - loss: 0.0396 - val_accuracy: 0.9917 - val_loss: 0.0306
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9891 - loss: 0.0370 - val_accuracy: 0.9908 - val_loss: 0.0297
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9881 - loss: 0.0359 - val_accuracy: 0.9913 - val_loss: 0.0301
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9889 - loss: 0.0329 - val_accuracy: 0.9908 - val_loss: 0.0295
# Test loss: 0.024092821404337883
# Test accuracy: 0.9912999868392944
# CPU times: total: 1min 6s
# Wall time: 1min 41s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.plot(h2.history['val_loss'],color='cyan',linestyle='dashdot')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor','Adam+Wgt'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.plot(h1.history['val_accuracy'],color='orange',linestyle='solid')
plt.plot(h2.history['val_accuracy'],color='cyan',linestyle='dashdot')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor','Adam+Wgt'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# ### 4th Model, Adam

# %%
h3=model_build('adam',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7619 - loss: 0.7854 - val_accuracy: 0.9780 - val_loss: 0.0856
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9642 - loss: 0.1209 - val_accuracy: 0.9828 - val_loss: 0.0616
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9726 - loss: 0.0890 - val_accuracy: 0.9862 - val_loss: 0.0514
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9765 - loss: 0.0751 - val_accuracy: 0.9880 - val_loss: 0.0436
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9802 - loss: 0.0645 - val_accuracy: 0.9883 - val_loss: 0.0405
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9813 - loss: 0.0584 - val_accuracy: 0.9888 - val_loss: 0.0371
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9828 - loss: 0.0520 - val_accuracy: 0.9897 - val_loss: 0.0342
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9843 - loss: 0.0481 - val_accuracy: 0.9900 - val_loss: 0.0340
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9855 - loss: 0.0460 - val_accuracy: 0.9910 - val_loss: 0.0307
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9865 - loss: 0.0429 - val_accuracy: 0.9903 - val_loss: 0.0321
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9871 - loss: 0.0392 - val_accuracy: 0.9912 - val_loss: 0.0295
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9884 - loss: 0.0354 - val_accuracy: 0.9913 - val_loss: 0.0297
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9885 - loss: 0.0364 - val_accuracy: 0.9913 - val_loss: 0.0323
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9886 - loss: 0.0352 - val_accuracy: 0.9920 - val_loss: 0.0295
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9891 - loss: 0.0328 - val_accuracy: 0.9917 - val_loss: 0.0300
# Test loss: 0.02564389631152153
# Test accuracy: 0.9914000034332275

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.plot(h2.history['val_loss'],color='cyan',linestyle='dashdot')
plt.plot(h3.history['val_loss'],color='pink',linestyle='dashed')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor','Adam+Wgt','Adam'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'], color='b',linestyle='solid')
plt.plot(h1.history['val_accuracy'], color='orange',linestyle='solid')
plt.plot(h2.history['val_accuracy'], color='cyan',linestyle='dashdot')
plt.plot(h3.history['val_accuracy'], color='pink',linestyle='dashed')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['LION','AdaFactor','Adam+Wgt','Adam'])
plt.grid()
plt.show()

# %% [markdown]
# #### Comment
# lorem ipsum
# # Conclusions
# Blah blah blah
