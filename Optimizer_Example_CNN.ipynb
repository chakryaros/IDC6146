# %% [markdown]
# # Optimizer Example
# MNIST CNN example showing comparison between optimizers.
#
# Richard Henry, 15-Jul-2024

# %%
#Import Libararies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# Test Libraries

# %%
# Check python version
from platform import python_version
print(python_version())
#3.12.3
# Out:
# 3.12.3

# %%
# Check tensorflow version
tf.__version__
#2.16.1
# Out:
# '2.16.2'

# %%
# Check keras version
tf.keras.__version__
#3.4.1
# Out:
# '3.4.1'

# %% [markdown]
# # Optimizer List

# %% [markdown]
# ## AdaDelta
# Adadelta optimization is a stochastic gradient descent method that is based on adaptive learning rate per dimension to address two drawbacks:
#
# - The continual decay of learning rates throughout training.
# - The need for a manually selected global learning rate.
#
# Adadelta is a more robust extension of Adagrad that adapts learning rates based on a moving window of gradient updates, instead of accumulating all past gradients. This way, Adadelta continues learning even when many updates have been done. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2012|
# |Short Cut|'adadelta'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adadelta

# %%
opt001=tf.keras.optimizers.Adadelta(
    learning_rate=0.001,
    rho=0.95,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adadelta'
)

# %% [markdown]
# ## AdaFactor
# Adafactor is commonly used in NLP tasks, and has the advantage of taking less memory because it only saves partial information of previous gradients. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2018|
# |Short Cut|'adafactor'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adafactor

# %%
opt002=tf.keras.optimizers.Adafactor(
    learning_rate=0.001,
    beta_2_decay=-0.8,
    epsilon_1=1e-30,
    epsilon_2=0.001,
    clip_threshold=1.0,
    relative_step=True,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adafactor'
)

# %% [markdown]
# ## AdaGrad
# Adagrad is an optimizer with parameter-specific learning rates, which are adapted relative to how frequently a parameter gets updated during training. The more updates a parameter receives, the smaller the updates. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2011|
# |Short Cut|'adagrad'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adagrad

# %%
opt003=tf.keras.optimizers.Adagrad(
    learning_rate=0.001,
    initial_accumulator_value=0.1,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adagrad'
)

# %% [markdown]
# ## ADAM
# Adam optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|duh|
# |Year|2015|
# |Short Cut|'adam'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam

# %%
opt000=tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adam'
)

# %% [markdown]
# ## ADAM with Weight Decay
# AdamW optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments with an added method to decay weights. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2019|
# |Short Cut|'adamw'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/AdamW

# %%
opt004=tf.keras.optimizers.AdamW(
    learning_rate=0.001,
    weight_decay=0.004,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adamw'
)

# %% [markdown]
# ## AdaMax
# A variant of Adam described in the same paper and based on the infinity norm, is a first-order gradient-based optimization method. Due to its capability of adjusting the learning rate based on data characteristics, it is suited to learn time-variant process, e.g., speech data with dynamically changed noise conditions. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2015|
# |Short Cut|'adamax'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adamax

# %%
opt005=tf.keras.optimizers.Adamax(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adamax'
)

# %% [markdown]
# ## Follow the Regularized Leader
# An optimization algorithm developed at Google for click-through rate prediction. It is most suitable for shallow models with large and sparse feature spaces. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2013|
# |Short Cut|'ftrl'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Ftrl

# %%
opt006=tf.keras.optimizers.Ftrl(
    learning_rate=0.001,
    learning_rate_power=-0.5,
    initial_accumulator_value=0.1,
    l1_regularization_strength=0.0,
    l2_regularization_strength=0.0,
    l2_shrinkage_regularization_strength=0.0,
    beta=0.0,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='ftrl'
)

# %% [markdown]
# ## Lion
# A stochastic-gradient-descent method that uses the sign operator to control the magnitude of the update, unlike other adaptive optimizers such as Adam that rely on second-order moments. This make Lion more memory-efficient as it only keeps track of the momentum. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Hell No|
# |Year|2023|
# |Short Cut|'lion'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Lion

# %%
opt007=tf.keras.optimizers.Lion(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.99,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='lion'
)

# %% [markdown]
# ## Adam with Nesterov Momentum
#
# Momentum is an approach that accelerates the progress of the search to skim across flat areas and smooth out bouncy gradients. [Brownlee]
# Nesterov momentum is an extension of momentum that involves calculating the decaying moving average of the gradients of projected positions in the search space rather than the actual positions themselves. [Also Brownlee]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2015|
# |Short Cut|'nadam'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam

# %%
opt008=tf.keras.optimizers.Nadam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='nadam'
)

# %% [markdown]
# ## Root Mean Square Propagation
# ADAM is an extension of this.
#
# The gist of RMSprop is to:
#
# - Maintain a moving (discounted) average of the square of gradients
# - Divide the gradient by the root of this average
#
# [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yup|
# |Year|2012|
# |Short Cut|'rmsprop'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/RMSprop

# %%
opt009=tf.keras.optimizers.RMSprop(
    learning_rate=0.001,
    rho=0.9,
    momentum=0.0,
    epsilon=1e-07,
    centered=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='rmsprop'
)

# %% [markdown]
# ## Stochastic Gradient Descent
# Gradient descent is an optimization algorithm that follows the negative gradient of an objective function in order to locate the minimum of the function. [Brownlee] Instead of updating weights based on the sum of the accumulated errors over all training examples, we update parameters incrementally for each training example. Although SGD can be considered an approximation of gradient descent, it typically reaches convergence faster because of more frequent weight updates.[Raschka]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'SGD'<-- notice CAPS!|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD

# %%
opt010=tf.keras.optimizers.SGD(
    learning_rate=0.01,
    momentum=0.0,
    nesterov=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='SGD'
)

# %% [markdown]
# ## SGD with Momentum
# Increase `momentum` above zero and below unity. Not sure it is used.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'mSGD'|
# |Default Setting|No|

# %%
opt011=tf.keras.optimizers.SGD(momentum=0.5,
                               name='mSGD'
                              )

# %% [markdown]
# ## SGD with Nesterov Momentum
# Increase `momentum` above zero and below unity. Set `nesterov` to `True`.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'nSGD'|
# |Default Setting|No|

# %%
opt012=tf.keras.optimizers.SGD(momentum=0.5,
                               nesterov=True,
                               name='nSGD'
                              )

# %% [markdown]
# ## RMSprop with Momentum
# Increase `momentum` above zero and below unity.  Notice we can't use Nesterov here.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|who knows|
# |Short Cut|'nRMS'|
# |Default Setting|No|

# %%
opt013=tf.keras.optimizers.RMSprop(momentum=0.5,
                                   name='nRMS'
                                  )

# %% [markdown]
# ## Natural Gradient Descent
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Unfortunately, yes|
# |Year|1998|
# |Short Cut|'NGD'|
# |Default Setting|No clue|
#
# Can we like, ignore this one?
#
# https://www.geeksforgeeks.org/optimizers-in-tensorflow/

# %%
opt999=tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.001, 
                                                    use_locking=True,
                                                    name = 'NGD')
# Out:
# WARNING:tensorflow:From C:\Users\brera\AppData\Local\Temp\ipykernel_21420\2360995615.py:1: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %% [markdown]
# ## Unavailable
# Optimizers mentioned in the article but not available in tensorflow 2
#
# - vSGD (Schaul et al, 2012)
#
# - natural Newton (Roux & Fitzgibbon, 2012)
#
# - SFO (Sohl & Dickstein, 2014)

# %% [markdown]
# # MNIST CNN
# This shows how I would build up a story by generating the same model several times and plot the results cumulatively.
#
# Adapted from Keras Documentation.
# https://keras.io/examples/vision/mnist_convnet/

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)
batch_size = 128
num_epochs = 15

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# Build & train model function
def model_build(myOpti,
                myClas,
                myShap,
                myBatc,
                myEpoc,
                myxTra,
                myyTra,
                myxTes,
                myyTes):
    #Build it exactly the same every time
    tf.random.set_seed(19) 
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape=myShap),
            #tf.keras.layers.Rescaling(1.0/255),
            tf.keras.layers.Conv2D(32, 
                                   kernel_size=(3, 3), 
                                   activation="relu"),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Conv2D(64, 
                                   kernel_size=(3, 3), 
                                   activation="relu"),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(myClas, 
                                  activation="softmax"),
        ]
    )
    model.compile(loss="categorical_crossentropy", 
                  optimizer=myOpti, 
                  metrics=["accuracy"])
    myHis=model.fit(myxTra, 
                    myyTra, 
                    batch_size=myBatc, 
                    epochs=myEpoc, 
                    validation_split=0.1)
    score = model.evaluate(myxTes, 
                           myyTes, 
                           verbose=0)
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])
    return myHis

# %% [markdown]
# ### First Model, RMSprop

# %%
# %%time
h0=model_build(opt008,num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.7580 - loss: 0.7854 - val_accuracy: 0.9767 - val_loss: 0.0834
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9610 - loss: 0.1268 - val_accuracy: 0.9837 - val_loss: 0.0612
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9731 - loss: 0.0888 - val_accuracy: 0.9863 - val_loss: 0.0488
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9758 - loss: 0.0763 - val_accuracy: 0.9883 - val_loss: 0.0436
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9798 - loss: 0.0658 - val_accuracy: 0.9893 - val_loss: 0.0399
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9825 - loss: 0.0564 - val_accuracy: 0.9900 - val_loss: 0.0355
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9833 - loss: 0.0538 - val_accuracy: 0.9893 - val_loss: 0.0348
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9843 - loss: 0.0497 - val_accuracy: 0.9905 - val_loss: 0.0309
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9851 - loss: 0.0457 - val_accuracy: 0.9910 - val_loss: 0.0311
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9856 - loss: 0.0427 - val_accuracy: 0.9912 - val_loss: 0.0302
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9882 - loss: 0.0381 - val_accuracy: 0.9913 - val_loss: 0.0296
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9875 - loss: 0.0379 - val_accuracy: 0.9893 - val_loss: 0.0308
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9881 - loss: 0.0365 - val_accuracy: 0.9917 - val_loss: 0.0293
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9880 - loss: 0.0361 - val_accuracy: 0.9923 - val_loss: 0.0283
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9894 - loss: 0.0318 - val_accuracy: 0.9925 - val_loss: 0.0262
# Test loss: 0.023027563467621803
# Test accuracy: 0.9915000200271606
# CPU times: total: 1min 22s
# Wall time: 1min 20s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# ### Second Model, AdaGrad

# %%
# %%time
h1=model_build('adagrad',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1873 - loss: 2.2752 - val_accuracy: 0.5150 - val_loss: 2.1381
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.4071 - loss: 2.0692 - val_accuracy: 0.7338 - val_loss: 1.6167
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.5770 - loss: 1.5468 - val_accuracy: 0.8263 - val_loss: 0.9740
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.6716 - loss: 1.0991 - val_accuracy: 0.8617 - val_loss: 0.6769
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7298 - loss: 0.8766 - val_accuracy: 0.8823 - val_loss: 0.5357
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7604 - loss: 0.7574 - val_accuracy: 0.8947 - val_loss: 0.4553
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.7866 - loss: 0.6761 - val_accuracy: 0.9075 - val_loss: 0.4018
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8081 - loss: 0.6134 - val_accuracy: 0.9127 - val_loss: 0.3637
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8246 - loss: 0.5689 - val_accuracy: 0.9183 - val_loss: 0.3345
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8355 - loss: 0.5323 - val_accuracy: 0.9218 - val_loss: 0.3115
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8450 - loss: 0.4970 - val_accuracy: 0.9255 - val_loss: 0.2923
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8566 - loss: 0.4720 - val_accuracy: 0.9293 - val_loss: 0.2765
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.8625 - loss: 0.4468 - val_accuracy: 0.9347 - val_loss: 0.2626
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.8687 - loss: 0.4272 - val_accuracy: 0.9373 - val_loss: 0.2515
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.8755 - loss: 0.4093 - val_accuracy: 0.9390 - val_loss: 0.2408
# Test loss: 0.27798011898994446
# Test accuracy: 0.927299976348877
# CPU times: total: 1min 18s
# Wall time: 1min 31s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.plot(h1.history['val_accuracy'],color='orange',linestyle='solid')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Impsum
# ### Third Model, SGD + Nesterov Mommentum

# %%
# %%time
h2=model_build(opt012,num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.4551 - loss: 1.6409 - val_accuracy: 0.9342 - val_loss: 0.2613
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.8825 - loss: 0.3828 - val_accuracy: 0.9590 - val_loss: 0.1632
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9206 - loss: 0.2630 - val_accuracy: 0.9663 - val_loss: 0.1304
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9345 - loss: 0.2126 - val_accuracy: 0.9700 - val_loss: 0.1111
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9442 - loss: 0.1857 - val_accuracy: 0.9730 - val_loss: 0.1005
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9510 - loss: 0.1651 - val_accuracy: 0.9747 - val_loss: 0.0918
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9506 - loss: 0.1554 - val_accuracy: 0.9755 - val_loss: 0.0847
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9564 - loss: 0.1435 - val_accuracy: 0.9770 - val_loss: 0.0806
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9591 - loss: 0.1340 - val_accuracy: 0.9793 - val_loss: 0.0760
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9601 - loss: 0.1283 - val_accuracy: 0.9803 - val_loss: 0.0729
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9610 - loss: 0.1244 - val_accuracy: 0.9803 - val_loss: 0.0703
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9637 - loss: 0.1182 - val_accuracy: 0.9812 - val_loss: 0.0673
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9656 - loss: 0.1115 - val_accuracy: 0.9833 - val_loss: 0.0641
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9650 - loss: 0.1120 - val_accuracy: 0.9825 - val_loss: 0.0640
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9681 - loss: 0.1057 - val_accuracy: 0.9842 - val_loss: 0.0622
# Test loss: 0.06078140437602997
# Test accuracy: 0.9818000197410583
# CPU times: total: 1min 43s
# Wall time: 1min 55s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.plot(h2.history['val_loss'],color='cyan',linestyle='dashdot')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.plot(h1.history['val_accuracy'],color='orange',linestyle='solid')
plt.plot(h2.history['val_accuracy'],color='cyan',linestyle='dashdot')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# ### 4th Model, Adam

# %%
h3=model_build('adam',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.7752 - loss: 0.7340 - val_accuracy: 0.9782 - val_loss: 0.0830
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9609 - loss: 0.1264 - val_accuracy: 0.9840 - val_loss: 0.0597
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9723 - loss: 0.0912 - val_accuracy: 0.9875 - val_loss: 0.0468
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9778 - loss: 0.0727 - val_accuracy: 0.9875 - val_loss: 0.0425
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9800 - loss: 0.0644 - val_accuracy: 0.9900 - val_loss: 0.0375
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9803 - loss: 0.0601 - val_accuracy: 0.9897 - val_loss: 0.0356
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9832 - loss: 0.0520 - val_accuracy: 0.9893 - val_loss: 0.0350
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9852 - loss: 0.0483 - val_accuracy: 0.9898 - val_loss: 0.0333
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9858 - loss: 0.0460 - val_accuracy: 0.9912 - val_loss: 0.0297
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9863 - loss: 0.0438 - val_accuracy: 0.9920 - val_loss: 0.0296
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9864 - loss: 0.0412 - val_accuracy: 0.9922 - val_loss: 0.0283
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9878 - loss: 0.0383 - val_accuracy: 0.9915 - val_loss: 0.0282
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9872 - loss: 0.0377 - val_accuracy: 0.9908 - val_loss: 0.0279
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9882 - loss: 0.0378 - val_accuracy: 0.9917 - val_loss: 0.0276
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9885 - loss: 0.0355 - val_accuracy: 0.9917 - val_loss: 0.0284
# Test loss: 0.025103919208049774
# Test accuracy: 0.9914000034332275

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.plot(h2.history['val_loss'],color='cyan',linestyle='dashdot')
plt.plot(h3.history['val_loss'],color='pink',linestyle='dashed')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest','Adam'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'], color='b',linestyle='solid')
plt.plot(h1.history['val_accuracy'], color='orange',linestyle='solid')
plt.plot(h2.history['val_accuracy'], color='cyan',linestyle='dashdot')
plt.plot(h3.history['val_accuracy'], color='pink',linestyle='dashed')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest','Adam'])
plt.grid()
plt.show()

# %% [markdown]
# #### Comment
# lorem ipsum
# # Conclusions
# Blah blah blah
