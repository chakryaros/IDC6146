# %% [markdown]
# # Optimizer Example
# MNIST CNN example showing comparison between optimizers.
#
# Richard Henry, 15-Jul-2024

# %%
#Import Libararies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# Test Libraries

# %%
# Check python version
from platform import python_version
print(python_version())
#3.12.3
# Out:
# 3.12.3

# %%
# Check tensorflow version
tf.__version__
#2.16.1
# Out:
# '2.16.2'

# %%
# Check keras version
tf.keras.__version__
#3.4.1
# Out:
# '3.4.1'

# %% [markdown]
# # MNIST CNN
# Here we compare Adam with optimizers mentioned in the paper.
#
# Adapted from Keras Documentation.
# https://keras.io/examples/vision/mnist_convnet/

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)
batch_size = 128
num_epochs = 15

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# Build & train model function
def model_build(myOpti,
                myClas,
                myShap,
                myBatc,
                myEpoc,
                myxTra,
                myyTra,
                myxTes,
                myyTes):
    #Build it exactly the same every time
    tf.random.set_seed(19) 
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape=myShap),
            #tf.keras.layers.Rescaling(1.0/255),
            tf.keras.layers.Conv2D(32, 
                                   kernel_size=(3, 3), 
                                   activation="relu"),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Conv2D(64, 
                                   kernel_size=(3, 3), 
                                   activation="relu"),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(myClas, 
                                  activation="softmax"),
        ]
    )
    model.compile(loss="categorical_crossentropy", 
                  optimizer=myOpti, 
                  metrics=["accuracy"])
    myHis=model.fit(myxTra, 
                    myyTra, 
                    batch_size=myBatc, 
                    epochs=myEpoc, 
                    validation_split=0.1)
    score = model.evaluate(myxTes, 
                           myyTes, 
                           verbose=0)
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])
    return myHis

# %% [markdown]
# ### First Model, RMSprop

# %%
# %%time
h0=model_build('rmsprop',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7850 - loss: 0.6917 - val_accuracy: 0.9738 - val_loss: 0.0903
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9585 - loss: 0.1360 - val_accuracy: 0.9825 - val_loss: 0.0596
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9697 - loss: 0.0982 - val_accuracy: 0.9847 - val_loss: 0.0503
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9766 - loss: 0.0778 - val_accuracy: 0.9872 - val_loss: 0.0432
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9788 - loss: 0.0677 - val_accuracy: 0.9852 - val_loss: 0.0458
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9795 - loss: 0.0625 - val_accuracy: 0.9887 - val_loss: 0.0391
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9830 - loss: 0.0546 - val_accuracy: 0.9892 - val_loss: 0.0368
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9831 - loss: 0.0549 - val_accuracy: 0.9888 - val_loss: 0.0368
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9841 - loss: 0.0504 - val_accuracy: 0.9898 - val_loss: 0.0347
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9844 - loss: 0.0470 - val_accuracy: 0.9913 - val_loss: 0.0325
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9849 - loss: 0.0457 - val_accuracy: 0.9902 - val_loss: 0.0334
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9861 - loss: 0.0429 - val_accuracy: 0.9893 - val_loss: 0.0329
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9876 - loss: 0.0393 - val_accuracy: 0.9902 - val_loss: 0.0307
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9870 - loss: 0.0408 - val_accuracy: 0.9917 - val_loss: 0.0306
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9880 - loss: 0.0375 - val_accuracy: 0.9918 - val_loss: 0.0297
# Test loss: 0.026080086827278137
# Test accuracy: 0.9916999936103821
# CPU times: total: 1min 26s
# Wall time: 2min 1s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# ### Second Model, AdaGrad

# %%
# %%time
h1=model_build('adagrad',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.1197 - loss: 2.2908 - val_accuracy: 0.5108 - val_loss: 2.1868
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.3412 - loss: 2.1408 - val_accuracy: 0.7317 - val_loss: 1.8255
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.5310 - loss: 1.7404 - val_accuracy: 0.8102 - val_loss: 1.1724
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6401 - loss: 1.2355 - val_accuracy: 0.8500 - val_loss: 0.7754
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7069 - loss: 0.9543 - val_accuracy: 0.8758 - val_loss: 0.5914
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7439 - loss: 0.8118 - val_accuracy: 0.8917 - val_loss: 0.4916
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7749 - loss: 0.7167 - val_accuracy: 0.9008 - val_loss: 0.4290
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7973 - loss: 0.6489 - val_accuracy: 0.9063 - val_loss: 0.3857
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8156 - loss: 0.5964 - val_accuracy: 0.9138 - val_loss: 0.3526
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8266 - loss: 0.5605 - val_accuracy: 0.9187 - val_loss: 0.3272
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8377 - loss: 0.5232 - val_accuracy: 0.9242 - val_loss: 0.3063
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8481 - loss: 0.4941 - val_accuracy: 0.9265 - val_loss: 0.2891
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8573 - loss: 0.4687 - val_accuracy: 0.9297 - val_loss: 0.2744
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8626 - loss: 0.4507 - val_accuracy: 0.9325 - val_loss: 0.2614
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8696 - loss: 0.4276 - val_accuracy: 0.9350 - val_loss: 0.2504
# Test loss: 0.2909718155860901
# Test accuracy: 0.9235000014305115
# CPU times: total: 1min 38s
# Wall time: 1min 58s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.plot(h1.history['val_accuracy'],color='orange',linestyle='solid')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Impsum
# ### Third Model, SGD + Nesterov Mommentum

# %%
opt012=tf.keras.optimizers.SGD(momentum=0.5,
                               nesterov=True,
                               name='nSGD'
                              )

# %%
# %%time
h2=model_build(opt012,num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.4913 - loss: 1.5618 - val_accuracy: 0.9377 - val_loss: 0.2460
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8867 - loss: 0.3682 - val_accuracy: 0.9583 - val_loss: 0.1580
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9230 - loss: 0.2536 - val_accuracy: 0.9670 - val_loss: 0.1267
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9368 - loss: 0.2075 - val_accuracy: 0.9703 - val_loss: 0.1114
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9447 - loss: 0.1828 - val_accuracy: 0.9735 - val_loss: 0.0990
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9489 - loss: 0.1666 - val_accuracy: 0.9747 - val_loss: 0.0905
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9547 - loss: 0.1514 - val_accuracy: 0.9767 - val_loss: 0.0857
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9573 - loss: 0.1417 - val_accuracy: 0.9782 - val_loss: 0.0800
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9585 - loss: 0.1362 - val_accuracy: 0.9792 - val_loss: 0.0764
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9613 - loss: 0.1264 - val_accuracy: 0.9797 - val_loss: 0.0731
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9614 - loss: 0.1247 - val_accuracy: 0.9808 - val_loss: 0.0697
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9637 - loss: 0.1168 - val_accuracy: 0.9803 - val_loss: 0.0679
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9647 - loss: 0.1149 - val_accuracy: 0.9818 - val_loss: 0.0658
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9658 - loss: 0.1093 - val_accuracy: 0.9815 - val_loss: 0.0634
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9692 - loss: 0.1023 - val_accuracy: 0.9832 - val_loss: 0.0628
# Test loss: 0.06471285969018936
# Test accuracy: 0.9800999760627747
# CPU times: total: 1min 51s
# Wall time: 2min 1s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.plot(h2.history['val_loss'],color='cyan',linestyle='dashdot')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.plot(h1.history['val_accuracy'],color='orange',linestyle='solid')
plt.plot(h2.history['val_accuracy'],color='cyan',linestyle='dashdot')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# ### 4th Model, Adam

# %%
# %%time
h3=model_build('adam',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7694 - loss: 0.7607 - val_accuracy: 0.9785 - val_loss: 0.0801
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9611 - loss: 0.1260 - val_accuracy: 0.9862 - val_loss: 0.0561
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9723 - loss: 0.0896 - val_accuracy: 0.9883 - val_loss: 0.0485
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9778 - loss: 0.0745 - val_accuracy: 0.9880 - val_loss: 0.0414
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9799 - loss: 0.0649 - val_accuracy: 0.9893 - val_loss: 0.0406
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9815 - loss: 0.0602 - val_accuracy: 0.9897 - val_loss: 0.0363
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9828 - loss: 0.0549 - val_accuracy: 0.9885 - val_loss: 0.0367
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9837 - loss: 0.0510 - val_accuracy: 0.9885 - val_loss: 0.0363
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9847 - loss: 0.0491 - val_accuracy: 0.9907 - val_loss: 0.0325
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9859 - loss: 0.0431 - val_accuracy: 0.9910 - val_loss: 0.0327
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9870 - loss: 0.0417 - val_accuracy: 0.9917 - val_loss: 0.0307
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9872 - loss: 0.0394 - val_accuracy: 0.9917 - val_loss: 0.0320
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9870 - loss: 0.0387 - val_accuracy: 0.9918 - val_loss: 0.0307
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9888 - loss: 0.0350 - val_accuracy: 0.9922 - val_loss: 0.0283
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9878 - loss: 0.0358 - val_accuracy: 0.9922 - val_loss: 0.0291
# Test loss: 0.024200445041060448
# Test accuracy: 0.9915000200271606
# CPU times: total: 1min 36s
# Wall time: 1min 58s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.plot(h2.history['val_loss'],color='cyan',linestyle='dashdot')
plt.plot(h3.history['val_loss'],color='magenta',linestyle='dashed')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest','Adam'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'], color='blue',linestyle='solid')
plt.plot(h1.history['val_accuracy'], color='orange',linestyle='solid')
plt.plot(h2.history['val_accuracy'], color='cyan',linestyle='dashdot')
plt.plot(h3.history['val_accuracy'], color='magenta',linestyle='dashed')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest','Adam'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'], color='blue',linestyle='solid')
plt.plot(h1.history['val_accuracy'], color='orange',linestyle='solid')
plt.plot(h2.history['val_accuracy'], color='cyan',linestyle='dashdot')
plt.plot(h3.history['val_accuracy'], color='magenta',linestyle='dashed')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest','Adam'])
plt.grid()
plt.ylim([0.96,1.00])
plt.show()

# %% [markdown]
# #### Comment
# lorem ipsum
# # Conclusions
# Blah blah blah
