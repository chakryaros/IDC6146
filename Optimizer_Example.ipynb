# %% [markdown]
# # Optimizer Example #
# MNIST Covnet example showing comparison between optimizers.
#
# Richard Henry, 15-Jul-2024

# %%
#Import Libararies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# Test Libraries

# %%
# Check python version
from platform import python_version
print(python_version())
#3.12.3
# Out:
# 3.12.3

# %%
# Check tensorflow version
tf.__version__
#2.16.1
# Out:
# '2.16.2'

# %%
# Check keras version
tf.keras.__version__
# Out:
# '3.4.1'

# %% [markdown]
# # Optimizer List #

# %% [markdown]
# ## AdaDelta ##
# Adadelta optimization is a stochastic gradient descent method that is based on adaptive learning rate per dimension to address two drawbacks:
#
# - The continual decay of learning rates throughout training.
# - The need for a manually selected global learning rate.
#
# Adadelta is a more robust extension of Adagrad that adapts learning rates based on a moving window of gradient updates, instead of accumulating all past gradients. This way, Adadelta continues learning even when many updates have been done. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2012|
# |Short Cut|'adadelta'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adadelta

# %%
opt001=tf.keras.optimizers.Adadelta(
    learning_rate=0.001,
    rho=0.95,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adadelta'
)

# %% [markdown]
# # AdaFactor #
# Adafactor is commonly used in NLP tasks, and has the advantage of taking less memory because it only saves partial information of previous gradients. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2018|
# |Short Cut|'adafactor'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adafactor

# %%
opt002=tf.keras.optimizers.Adafactor(
    learning_rate=0.001,
    beta_2_decay=-0.8,
    epsilon_1=1e-30,
    epsilon_2=0.001,
    clip_threshold=1.0,
    relative_step=True,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adafactor'
)

# %% [markdown]
# # AdaGrad #
# Adagrad is an optimizer with parameter-specific learning rates, which are adapted relative to how frequently a parameter gets updated during training. The more updates a parameter receives, the smaller the updates. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2011|
# |Short Cut|'adagrad'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adagrad

# %%
opt003=tf.keras.optimizers.Adagrad(
    learning_rate=0.001,
    initial_accumulator_value=0.1,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adagrad'
)

# %% [markdown]
# # ADAM #
# Adam optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|duh|
# |Year|2015|
# |Short Cut|'adam'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam

# %%
opt000=tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adam'
)

# %% [markdown]
# # ADAM with Weight Decay #
# AdamW optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments with an added method to decay weights. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2019|
# |Short Cut|'adamw'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/AdamW

# %%
opt004=tf.keras.optimizers.AdamW(
    learning_rate=0.001,
    weight_decay=0.004,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adamw'
)

# %% [markdown]
# # AdaMax #
# A variant of Adam described in the same paper and based on the infinity norm, is a first-order gradient-based optimization method. Due to its capability of adjusting the learning rate based on data characteristics, it is suited to learn time-variant process, e.g., speech data with dynamically changed noise conditions. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2015|
# |Short Cut|'adamax'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adamax

# %%
opt005=tf.keras.optimizers.Adamax(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adamax'
)

# %% [markdown]
# # Follow the Regularized Leader #
# An optimization algorithm developed at Google for click-through rate prediction. It is most suitable for shallow models with large and sparse feature spaces. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2013|
# |Short Cut|'ftrl'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Ftrl

# %%
opt006=tf.keras.optimizers.Ftrl(
    learning_rate=0.001,
    learning_rate_power=-0.5,
    initial_accumulator_value=0.1,
    l1_regularization_strength=0.0,
    l2_regularization_strength=0.0,
    l2_shrinkage_regularization_strength=0.0,
    beta=0.0,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='ftrl'
)

# %% [markdown]
# # Lion #
# A stochastic-gradient-descent method that uses the sign operator to control the magnitude of the update, unlike other adaptive optimizers such as Adam that rely on second-order moments. This make Lion more memory-efficient as it only keeps track of the momentum. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Hell No|
# |Year|2023|
# |Short Cut|'lion'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Lion

# %%
opt007=tf.keras.optimizers.Lion(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.99,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='lion'
)

# %% [markdown]
# # Adam with Nesterov momentum #
#
# Momentum is an approach that accelerates the progress of the search to skim across flat areas and smooth out bouncy gradients. [Brownlee]
# Nesterov momentum is an extension of momentum that involves calculating the decaying moving average of the gradients of projected positions in the search space rather than the actual positions themselves. [Also Brownlee]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2015|
# |Short Cut|'nadam'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam

# %%
opt008=tf.keras.optimizers.Nadam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='nadam'
)

# %% [markdown]
# # Root Mean Square Propagation #
# ADAM is an extension of this.
#
# The gist of RMSprop is to:
#
# - Maintain a moving (discounted) average of the square of gradients
# - Divide the gradient by the root of this average
#
# [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yup|
# |Year|2012|
# |Short Cut|'rmsprop'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/RMSprop

# %%
opt009=tf.keras.optimizers.RMSprop(
    learning_rate=0.001,
    rho=0.9,
    momentum=0.0,
    epsilon=1e-07,
    centered=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='rmsprop'
)

# %% [markdown]
# # Stochastic Gradient Descent #
# Gradient descent is an optimization algorithm that follows the negative gradient of an objective function in order to locate the minimum of the function. [Brownlee] Instead of updating weights based on the sum of the accumulated errors over all training examples, we update parameters incrementally for each training example. Although SGD can be considered an approximation of gradient descent, it typically reaches convergence faster because of more frequent weight updates.[Raschka]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'SGD'<-- notice CAPS!|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD

# %%
opt010=tf.keras.optimizers.SGD(
    learning_rate=0.01,
    momentum=0.0,
    nesterov=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='SGD'
)

# %% [markdown]
# # SGD with Momentum #
# Increase `momentum` above zero and below unity. Not sure it is used.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'mSGD'|
# |Default Setting|No|

# %%
opt011=tf.keras.optimizers.SGD(momentum=0.5,
                               name='mSGD'
                              )

# %% [markdown]
# # SGD with Nesterov Momentum #
# Increase `momentum` above zero and below unity. Set `nesterov` to `True`.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'nSGD'|
# |Default Setting|No|

# %%
opt012=tf.keras.optimizers.SGD(momentum=0.5,
                               nesterov=True,
                               name='nSGD'
                              )

# %% [markdown]
# # RMSprop with Momentum #
# Increase `momentum` above zero and below unity.  Notice we can't use Nesterov here.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|who knows|
# |Short Cut|'nRMS'|
# |Default Setting|No|

# %%
opt013=tf.keras.optimizers.RMSprop(momentum=0.5,
                                   name='nRMS'
                                  )

# %% [markdown]
# # Natural Gradient Descent #
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Unfortunately, yes|
# |Year|1998|
# |Short Cut|'NGD'|
# |Default Setting|No clue|
#
# Can we like, ignore this one?
#
# https://www.geeksforgeeks.org/optimizers-in-tensorflow/

# %%
opt999=tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.001, 
                                                    use_locking=True,
                                                    name = 'NGD')
# Out:
# WARNING:tensorflow:From C:\Users\brera\AppData\Local\Temp\ipykernel_13308\2360995615.py:1: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %% [markdown]
# # Unavailable #
# Optimizers mentioned in the article but not available in tensorflow 2
#
# - vSGD (Schaul et al, 2012)
#
# - natural Newton (Roux & Fitzgibbon, 2012)
#
# - SFO (Sohl & Dickstein, 2014)

# %% [markdown]
# # MNIST Covnet #
# This shows how I would build up a story by generating the same model several times and plot the results cumulatively.
#
# Adapted from Keras Documentation.
# https://keras.io/examples/vision/mnist_convnet/

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)
batch_size = 128
num_epochs = 15

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# Build & train model function
def model_build(myOpti,
                myClas,
                myShap,
                myBatc,
                myEpoc,
                myxTra,
                myyTra,
                myxTes,
                myyTes):
    #Build it exactly the same every time
    tf.random.set_seed(19) 
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape=myShap),
            #tf.keras.layers.Rescaling(1.0/255),
            tf.keras.layers.Conv2D(32, 
                                   kernel_size=(3, 3), 
                                   activation="relu"),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Conv2D(64, 
                                   kernel_size=(3, 3), 
                                   activation="relu"),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(myClas, 
                                  activation="softmax"),
        ]
    )
    model.compile(loss="categorical_crossentropy", 
                  optimizer=myOpti, 
                  metrics=["accuracy"])
    myHis=model.fit(myxTra, 
                    myyTra, 
                    batch_size=myBatc, 
                    epochs=myEpoc, 
                    validation_split=0.1)
    score = model.evaluate(myxTes, 
                           myyTes, 
                           verbose=0)
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])
    return myHis

# %% [markdown]
# ### First Model, RMSprop ###

# %%
h0=model_build(opt008,num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.7723 - loss: 0.7579 - val_accuracy: 0.9802 - val_loss: 0.0791
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9630 - loss: 0.1215 - val_accuracy: 0.9842 - val_loss: 0.0568
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9730 - loss: 0.0884 - val_accuracy: 0.9873 - val_loss: 0.0457
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9777 - loss: 0.0741 - val_accuracy: 0.9893 - val_loss: 0.0409
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9798 - loss: 0.0625 - val_accuracy: 0.9905 - val_loss: 0.0367
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9815 - loss: 0.0590 - val_accuracy: 0.9905 - val_loss: 0.0341
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9823 - loss: 0.0533 - val_accuracy: 0.9912 - val_loss: 0.0326
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9849 - loss: 0.0467 - val_accuracy: 0.9903 - val_loss: 0.0339
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9856 - loss: 0.0452 - val_accuracy: 0.9918 - val_loss: 0.0319
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9861 - loss: 0.0437 - val_accuracy: 0.9922 - val_loss: 0.0311
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9880 - loss: 0.0392 - val_accuracy: 0.9910 - val_loss: 0.0314
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9876 - loss: 0.0375 - val_accuracy: 0.9923 - val_loss: 0.0293
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9882 - loss: 0.0368 - val_accuracy: 0.9928 - val_loss: 0.0281
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9891 - loss: 0.0323 - val_accuracy: 0.9925 - val_loss: 0.0290
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9894 - loss: 0.0316 - val_accuracy: 0.9925 - val_loss: 0.0285
# Test loss: 0.025724846869707108
# Test accuracy: 0.991599977016449

# %%
plt.plot(h0.history['val_loss'])
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary ####
# Lorem Ipsum
# ### Second Model, SGD with Mommentum ###

# %%
h1=model_build(opt011,num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.4504 - loss: 1.6667 - val_accuracy: 0.9335 - val_loss: 0.2622
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.8825 - loss: 0.3801 - val_accuracy: 0.9572 - val_loss: 0.1604
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9206 - loss: 0.2614 - val_accuracy: 0.9665 - val_loss: 0.1254
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9352 - loss: 0.2096 - val_accuracy: 0.9707 - val_loss: 0.1091
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9449 - loss: 0.1808 - val_accuracy: 0.9738 - val_loss: 0.0968
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9498 - loss: 0.1638 - val_accuracy: 0.9763 - val_loss: 0.0885
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9533 - loss: 0.1500 - val_accuracy: 0.9772 - val_loss: 0.0838
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9566 - loss: 0.1409 - val_accuracy: 0.9793 - val_loss: 0.0782
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9596 - loss: 0.1302 - val_accuracy: 0.9793 - val_loss: 0.0743
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9632 - loss: 0.1221 - val_accuracy: 0.9812 - val_loss: 0.0706
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9639 - loss: 0.1179 - val_accuracy: 0.9818 - val_loss: 0.0683
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9648 - loss: 0.1134 - val_accuracy: 0.9825 - val_loss: 0.0659
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9652 - loss: 0.1110 - val_accuracy: 0.9832 - val_loss: 0.0637
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9696 - loss: 0.1032 - val_accuracy: 0.9838 - val_loss: 0.0610
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9690 - loss: 0.1001 - val_accuracy: 0.9837 - val_loss: 0.0591
# Test loss: 0.06032826006412506
# Test accuracy: 0.98089998960495

# %%
plt.plot(h0.history['val_loss'])
plt.plot(h1.history['val_loss'])
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','SGD+Mom'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'])
plt.plot(h1.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','SGD+Mom'])
plt.grid()
plt.show()

# %%
h2=model_build(opt000,num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.7642 - loss: 0.7760 - val_accuracy: 0.9765 - val_loss: 0.0849
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9634 - loss: 0.1190 - val_accuracy: 0.9837 - val_loss: 0.0595
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9734 - loss: 0.0867 - val_accuracy: 0.9865 - val_loss: 0.0465
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9787 - loss: 0.0695 - val_accuracy: 0.9865 - val_loss: 0.0435
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9797 - loss: 0.0631 - val_accuracy: 0.9887 - val_loss: 0.0374
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9831 - loss: 0.0556 - val_accuracy: 0.9885 - val_loss: 0.0362
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9837 - loss: 0.0506 - val_accuracy: 0.9885 - val_loss: 0.0348
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9844 - loss: 0.0476 - val_accuracy: 0.9910 - val_loss: 0.0331
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9865 - loss: 0.0433 - val_accuracy: 0.9910 - val_loss: 0.0312
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9868 - loss: 0.0412 - val_accuracy: 0.9915 - val_loss: 0.0293
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9881 - loss: 0.0372 - val_accuracy: 0.9915 - val_loss: 0.0297
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9881 - loss: 0.0362 - val_accuracy: 0.9913 - val_loss: 0.0316
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9882 - loss: 0.0366 - val_accuracy: 0.9913 - val_loss: 0.0280
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9896 - loss: 0.0335 - val_accuracy: 0.9915 - val_loss: 0.0288
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9895 - loss: 0.0314 - val_accuracy: 0.9922 - val_loss: 0.0281
# Test loss: 0.02417207881808281
# Test accuracy: 0.9915000200271606

# %% [markdown]
# #### Commentary ####
# Lorem Impsum
# ### Third Model, ADAM ###

# %%
plt.plot(h0.history['val_loss'])
plt.plot(h1.history['val_loss'])
plt.plot(h2.history['val_loss'])
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','SGD+Mom','ADAM'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'])
plt.plot(h1.history['val_accuracy'])
plt.plot(h2.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','SGD+Mom','ADAM'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary ####
# Lorem Ipsum
# # Conclusions #
# Blah blah blah
