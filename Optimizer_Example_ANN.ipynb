# %% [markdown]
# # Optimizer Example
# MNIST ANN example showing comparison between optimizers.
#
# Richard Henry, 15-Jul-2024

# %%
#Import Libararies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# Test Libraries

# %%
# Check python version
from platform import python_version
print(python_version())
#3.12.3
# Out:
# 3.12.3

# %%
# Check tensorflow version
tf.__version__
#2.16.1
# Out:
# '2.16.2'

# %%
# Check keras version
tf.keras.__version__
#3.4.1
# Out:
# '3.4.1'

# %% [markdown]
# # Optimizer List

# %% [markdown]
# ## AdaDelta
# Adadelta optimization is a stochastic gradient descent method that is based on adaptive learning rate per dimension to address two drawbacks:
#
# - The continual decay of learning rates throughout training.
# - The need for a manually selected global learning rate.
#
# Adadelta is a more robust extension of Adagrad that adapts learning rates based on a moving window of gradient updates, instead of accumulating all past gradients. This way, Adadelta continues learning even when many updates have been done. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2012|
# |Short Cut|'adadelta'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adadelta

# %%
opt001=tf.keras.optimizers.Adadelta(
    learning_rate=0.001,
    rho=0.95,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adadelta'
)

# %% [markdown]
# ## AdaFactor
# Adafactor is commonly used in NLP tasks, and has the advantage of taking less memory because it only saves partial information of previous gradients. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2018|
# |Short Cut|'adafactor'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adafactor

# %%
opt002=tf.keras.optimizers.Adafactor(
    learning_rate=0.001,
    beta_2_decay=-0.8,
    epsilon_1=1e-30,
    epsilon_2=0.001,
    clip_threshold=1.0,
    relative_step=True,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adafactor'
)

# %% [markdown]
# ## AdaGrad
# Adagrad is an optimizer with parameter-specific learning rates, which are adapted relative to how frequently a parameter gets updated during training. The more updates a parameter receives, the smaller the updates. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2011|
# |Short Cut|'adagrad'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adagrad

# %%
opt003=tf.keras.optimizers.Adagrad(
    learning_rate=0.001,
    initial_accumulator_value=0.1,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adagrad'
)

# %% [markdown]
# ## ADAM
# Adam optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|duh|
# |Year|2015|
# |Short Cut|'adam'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam

# %%
opt000=tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adam'
)

# %% [markdown]
# ## ADAM with Weight Decay
# AdamW optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments with an added method to decay weights. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2019|
# |Short Cut|'adamw'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/AdamW

# %%
opt004=tf.keras.optimizers.AdamW(
    learning_rate=0.001,
    weight_decay=0.004,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adamw'
)

# %% [markdown]
# ## AdaMax
# A variant of Adam described in the same paper and based on the infinity norm, is a first-order gradient-based optimization method. Due to its capability of adjusting the learning rate based on data characteristics, it is suited to learn time-variant process, e.g., speech data with dynamically changed noise conditions. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|2015|
# |Short Cut|'adamax'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adamax

# %%
opt005=tf.keras.optimizers.Adamax(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='adamax'
)

# %% [markdown]
# ## Follow the Regularized Leader
# An optimization algorithm developed at Google for click-through rate prediction. It is most suitable for shallow models with large and sparse feature spaces. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2013|
# |Short Cut|'ftrl'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Ftrl

# %%
opt006=tf.keras.optimizers.Ftrl(
    learning_rate=0.001,
    learning_rate_power=-0.5,
    initial_accumulator_value=0.1,
    l1_regularization_strength=0.0,
    l2_regularization_strength=0.0,
    l2_shrinkage_regularization_strength=0.0,
    beta=0.0,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='ftrl'
)

# %% [markdown]
# ## Lion
# A stochastic-gradient-descent method that uses the sign operator to control the magnitude of the update, unlike other adaptive optimizers such as Adam that rely on second-order moments. This make Lion more memory-efficient as it only keeps track of the momentum. [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Hell No|
# |Year|2023|
# |Short Cut|'lion'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Lion

# %%
opt007=tf.keras.optimizers.Lion(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.99,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='lion'
)

# %% [markdown]
# ## Adam with Nesterov Momentum
#
# Momentum is an approach that accelerates the progress of the search to skim across flat areas and smooth out bouncy gradients. [Brownlee]
# Nesterov momentum is an extension of momentum that involves calculating the decaying moving average of the gradients of projected positions in the search space rather than the actual positions themselves. [Also Brownlee]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|No|
# |Year|2015|
# |Short Cut|'nadam'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam

# %%
opt008=tf.keras.optimizers.Nadam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='nadam'
)

# %% [markdown]
# ## Root Mean Square Propagation
# ADAM is an extension of this.
#
# The gist of RMSprop is to:
#
# - Maintain a moving (discounted) average of the square of gradients
# - Divide the gradient by the root of this average
#
# [tensorflow docs]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yup|
# |Year|2012|
# |Short Cut|'rmsprop'|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/RMSprop

# %%
opt009=tf.keras.optimizers.RMSprop(
    learning_rate=0.001,
    rho=0.9,
    momentum=0.0,
    epsilon=1e-07,
    centered=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='rmsprop'
)

# %% [markdown]
# ## Stochastic Gradient Descent
# Gradient descent is an optimization algorithm that follows the negative gradient of an objective function in order to locate the minimum of the function. [Brownlee] Instead of updating weights based on the sum of the accumulated errors over all training examples, we update parameters incrementally for each training example. Although SGD can be considered an approximation of gradient descent, it typically reaches convergence faster because of more frequent weight updates.[Raschka]
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'SGD'<-- notice CAPS!|
# |Default Setting|Yes|
#
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD

# %%
opt010=tf.keras.optimizers.SGD(
    learning_rate=0.01,
    momentum=0.0,
    nesterov=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    loss_scale_factor=None,
    gradient_accumulation_steps=None,
    name='SGD'
)

# %% [markdown]
# ## SGD with Momentum
# Increase `momentum` above zero and below unity. Not sure it is used.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'mSGD'|
# |Default Setting|No|

# %%
opt011=tf.keras.optimizers.SGD(momentum=0.5,
                               name='mSGD'
                              )

# %% [markdown]
# ## SGD with Nesterov Momentum
# Increase `momentum` above zero and below unity. Set `nesterov` to `True`.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|a really long time ago|
# |Short Cut|'nSGD'|
# |Default Setting|No|

# %%
opt012=tf.keras.optimizers.SGD(momentum=0.5,
                               nesterov=True,
                               name='nSGD'
                              )

# %% [markdown]
# ## RMSprop with Momentum
# Increase `momentum` above zero and below unity.  Notice we can't use Nesterov here.
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Yes|
# |Year|who knows|
# |Short Cut|'nRMS'|
# |Default Setting|No|

# %%
opt013=tf.keras.optimizers.RMSprop(momentum=0.5,
                                   name='nRMS'
                                  )

# %% [markdown]
# ## Natural Gradient Descent
#
# |Variable|Value|
# |---|---|
# |Mentioned in Article|Unfortunately, yes|
# |Year|1998|
# |Short Cut|'NGD'|
# |Default Setting|No clue|
#
# Can we like, ignore this one?
#
# https://www.geeksforgeeks.org/optimizers-in-tensorflow/

# %%
opt999=tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.001, 
                                                    use_locking=True,
                                                    name = 'NGD')
# Out:
# WARNING:tensorflow:From C:\Users\brera\AppData\Local\Temp\ipykernel_12804\2360995615.py:1: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %% [markdown]
# ## Unavailable
# Optimizers mentioned in the article but not available in tensorflow 2
#
# - vSGD (Schaul et al, 2012)
#
# - natural Newton (Roux & Fitzgibbon, 2012)
#
# - SFO (Sohl & Dickstein, 2014)

# %% [markdown]
# # MNIST ANN
# This shows how I would build up a story by generating the same model several times and plot the results cumulatively.
#
# Adapted from mvsjober on Github.
# https://github.com/CSCfi/machine-learning-scripts/blob/master/notebooks/keras-mnist-mlp.ipynb

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28)
batch_size = 128
num_epochs = 15

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
#x_train = np.expand_dims(x_train, -1)
#x_test = np.expand_dims(x_test, -1)
# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# Build & train model function
def model_build(myOpti,
                myClas,
                myShap,
                myBatc,
                myEpoc,
                myxTra,
                myyTra,
                myxTes,
                myyTes):
    #Build it exactly the same every time
    tf.random.set_seed(19) 
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape=myShap),
            #tf.keras.layers.Rescaling(1.0/255),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(128, 
                                  activation="relu"),
            tf.keras.layers.Dropout(0.25),
            tf.keras.layers.Dense(64, 
                                  activation="relu"),
            tf.keras.layers.Dropout(0.15),
            tf.keras.layers.Dense(myClas, 
                                  activation="softmax"),
        ]
    )
    model.compile(loss="categorical_crossentropy", 
                  optimizer=myOpti, 
                  metrics=["accuracy"])
    myHis=model.fit(myxTra, 
                    myyTra, 
                    batch_size=myBatc, 
                    epochs=myEpoc, 
                    validation_split=0.1)
    score = model.evaluate(myxTes, 
                           myyTes, 
                           verbose=0)
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])
    return myHis

# %% [markdown]
# ### First Model, RMSprop

# %%
# %%time
h0=model_build(opt008,num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7384 - loss: 0.8322 - val_accuracy: 0.9575 - val_loss: 0.1486
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9287 - loss: 0.2408 - val_accuracy: 0.9683 - val_loss: 0.1067
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9452 - loss: 0.1773 - val_accuracy: 0.9723 - val_loss: 0.0901
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9562 - loss: 0.1461 - val_accuracy: 0.9747 - val_loss: 0.0817
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9620 - loss: 0.1231 - val_accuracy: 0.9770 - val_loss: 0.0773
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9666 - loss: 0.1092 - val_accuracy: 0.9767 - val_loss: 0.0728
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9696 - loss: 0.0964 - val_accuracy: 0.9775 - val_loss: 0.0689
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9719 - loss: 0.0881 - val_accuracy: 0.9800 - val_loss: 0.0689
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9744 - loss: 0.0818 - val_accuracy: 0.9802 - val_loss: 0.0657
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9750 - loss: 0.0792 - val_accuracy: 0.9800 - val_loss: 0.0678
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9767 - loss: 0.0725 - val_accuracy: 0.9775 - val_loss: 0.0717
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9786 - loss: 0.0662 - val_accuracy: 0.9813 - val_loss: 0.0618
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9785 - loss: 0.0638 - val_accuracy: 0.9812 - val_loss: 0.0637
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9795 - loss: 0.0595 - val_accuracy: 0.9817 - val_loss: 0.0613
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9813 - loss: 0.0566 - val_accuracy: 0.9800 - val_loss: 0.0666
# Test loss: 0.07220520824193954
# Test accuracy: 0.979200005531311
# CPU times: total: 5.55 s
# Wall time: 16.7 s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# ### Second Model, AdaGrad

# %%
# %%time
h1=model_build('adagrad',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1907 - loss: 2.2441 - val_accuracy: 0.5818 - val_loss: 1.7645
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4738 - loss: 1.7535 - val_accuracy: 0.7593 - val_loss: 1.2839
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6231 - loss: 1.3737 - val_accuracy: 0.8308 - val_loss: 0.9464
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6824 - loss: 1.1254 - val_accuracy: 0.8618 - val_loss: 0.7499
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7177 - loss: 0.9739 - val_accuracy: 0.8777 - val_loss: 0.6322
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7456 - loss: 0.8670 - val_accuracy: 0.8880 - val_loss: 0.5553
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7640 - loss: 0.7939 - val_accuracy: 0.8950 - val_loss: 0.5014
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7779 - loss: 0.7479 - val_accuracy: 0.8993 - val_loss: 0.4619
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.6976 - val_accuracy: 0.9037 - val_loss: 0.4303
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8056 - loss: 0.6612 - val_accuracy: 0.9070 - val_loss: 0.4056
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8099 - loss: 0.6376 - val_accuracy: 0.9100 - val_loss: 0.3855
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8171 - loss: 0.6142 - val_accuracy: 0.9123 - val_loss: 0.3688
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8263 - loss: 0.5908 - val_accuracy: 0.9160 - val_loss: 0.3542
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8315 - loss: 0.5712 - val_accuracy: 0.9168 - val_loss: 0.3421
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8374 - loss: 0.5546 - val_accuracy: 0.9183 - val_loss: 0.3311
# Test loss: 0.37596362829208374
# Test accuracy: 0.9031000137329102
# CPU times: total: 4.2 s
# Wall time: 13.1 s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.plot(h1.history['val_accuracy'],color='orange',linestyle='solid')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Impsum
# ### Third Model, SGD + Nesterov Mommentum

# %%
# %%time
h2=model_build(opt012,num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4476 - loss: 1.6777 - val_accuracy: 0.8873 - val_loss: 0.4651
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8053 - loss: 0.6398 - val_accuracy: 0.9143 - val_loss: 0.3138
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8527 - loss: 0.4890 - val_accuracy: 0.9262 - val_loss: 0.2618
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8745 - loss: 0.4218 - val_accuracy: 0.9327 - val_loss: 0.2296
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8877 - loss: 0.3786 - val_accuracy: 0.9403 - val_loss: 0.2093
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8968 - loss: 0.3487 - val_accuracy: 0.9448 - val_loss: 0.1913
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9044 - loss: 0.3185 - val_accuracy: 0.9478 - val_loss: 0.1790
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9120 - loss: 0.2971 - val_accuracy: 0.9530 - val_loss: 0.1671
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9162 - loss: 0.2855 - val_accuracy: 0.9557 - val_loss: 0.1572
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9214 - loss: 0.2656 - val_accuracy: 0.9587 - val_loss: 0.1485
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9234 - loss: 0.2523 - val_accuracy: 0.9595 - val_loss: 0.1423
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9273 - loss: 0.2445 - val_accuracy: 0.9620 - val_loss: 0.1351
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9294 - loss: 0.2340 - val_accuracy: 0.9642 - val_loss: 0.1305
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9332 - loss: 0.2240 - val_accuracy: 0.9657 - val_loss: 0.1248
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9351 - loss: 0.2159 - val_accuracy: 0.9663 - val_loss: 0.1217
# Test loss: 0.14152374863624573
# Test accuracy: 0.9559000134468079
# CPU times: total: 3.3 s
# Wall time: 13.1 s

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.plot(h2.history['val_loss'],color='cyan',linestyle='dashdot')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'],color='blue',linestyle='solid')
plt.plot(h1.history['val_accuracy'],color='orange',linestyle='solid')
plt.plot(h2.history['val_accuracy'],color='cyan',linestyle='dashdot')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest'])
plt.grid()
plt.show()

# %% [markdown]
# #### Commentary
# Lorem Ipsum
# ### 4th Model, Adam

# %%
h3=model_build('adam',num_classes,input_shape,batch_size,num_epochs,x_train,y_train,x_test,y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7552 - loss: 0.8084 - val_accuracy: 0.9580 - val_loss: 0.1448
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9298 - loss: 0.2384 - val_accuracy: 0.9718 - val_loss: 0.1019
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9458 - loss: 0.1766 - val_accuracy: 0.9752 - val_loss: 0.0879
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9563 - loss: 0.1440 - val_accuracy: 0.9767 - val_loss: 0.0811
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9629 - loss: 0.1227 - val_accuracy: 0.9787 - val_loss: 0.0758
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9675 - loss: 0.1071 - val_accuracy: 0.9783 - val_loss: 0.0762
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9698 - loss: 0.0957 - val_accuracy: 0.9783 - val_loss: 0.0724
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9734 - loss: 0.0872 - val_accuracy: 0.9783 - val_loss: 0.0766
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9727 - loss: 0.0835 - val_accuracy: 0.9815 - val_loss: 0.0682
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9744 - loss: 0.0804 - val_accuracy: 0.9810 - val_loss: 0.0663
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9774 - loss: 0.0701 - val_accuracy: 0.9797 - val_loss: 0.0683
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9791 - loss: 0.0665 - val_accuracy: 0.9810 - val_loss: 0.0678
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9797 - loss: 0.0607 - val_accuracy: 0.9810 - val_loss: 0.0687
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9818 - loss: 0.0565 - val_accuracy: 0.9808 - val_loss: 0.0724
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9813 - loss: 0.0570 - val_accuracy: 0.9813 - val_loss: 0.0686
# Test loss: 0.07468287646770477
# Test accuracy: 0.9778000116348267

# %%
plt.plot(h0.history['val_loss'],color='blue',linestyle='solid')
plt.plot(h1.history['val_loss'],color='orange',linestyle='solid')
plt.plot(h2.history['val_loss'],color='cyan',linestyle='dashdot')
plt.plot(h3.history['val_loss'],color='pink',linestyle='dashed')
plt.ylabel('Categorical Crossentropy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest','Adam'])
plt.grid()
plt.show()

# %%
plt.plot(h0.history['val_accuracy'], color='b',linestyle='solid')
plt.plot(h1.history['val_accuracy'], color='orange',linestyle='solid')
plt.plot(h2.history['val_accuracy'], color='cyan',linestyle='dashdot')
plt.plot(h3.history['val_accuracy'], color='pink',linestyle='dashed')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['RMSprop','AdaGrad','SGD+Nest','Adam'])
plt.grid()
plt.show()

# %% [markdown]
# #### Comment
# lorem ipsum
# # Conclusions
# Blah blah blah
